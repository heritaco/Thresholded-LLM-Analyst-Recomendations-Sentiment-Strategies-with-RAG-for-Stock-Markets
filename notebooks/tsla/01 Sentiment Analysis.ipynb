# %%
from scripts.load_data import load_triplet_news_txt

df_news = load_triplet_news_txt("data/TSLA.txt")
df_news
# Out:
#                                                  title date_raw source_code  \
# 0    Sector Update: Consumer Stocks Slide Late Afte...  Dec. 08          MT
# 1    Sector Update: Consumer Stocks Fall Monday Aft...  Dec. 08          MT
# 2    Tesla to See 'Choppy' Trading Backdrop Over Ne...  Dec. 08          MT
# 3    Tesla Faces Challenging EV Outlook, Morgan Sta...  Dec. 08          MT
# 4    Analyst recommendations: 3M Company, Exxon Mob...  Dec. 08  Zonebourse
# ..                                                 ...      ...         ...
# 389               TESLA : RBC reaffirms its Buy rating  Jan. 02          ZD
# 390                  TESLA : UBS remains a Sell rating  Jan. 02          ZD
# 391    TESLA : Jefferies reiterates its Neutral rating  Jan. 02          ZD
# 392  Truist Securities Cuts Price Target on Tesla t...  Jan. 02          MT
# 393  Tesla Q4 Deliveries Shy of Market Expectations...  Jan. 02          MT
#
#                                                   body
# 0    Sector Update: Consumer Stocks Slide Late Afte...
# 1    Sector Update: Consumer Stocks Fall Monday Aft...
# 2    Tesla to See 'Choppy' Trading Backdrop Over Ne...
# 3    Tesla Faces Challenging EV Outlook, Morgan Sta...
# 4    Analyst recommendations: 3M Company, Exxon Mob...
# ..                                                 ...
# 389               TESLA : RBC reaffirms its Buy rating
# 390                  TESLA : UBS remains a Sell rating
# 391    TESLA : Jefferies reiterates its Neutral rating
# 392  Truist Securities Cuts Price Target on Tesla t...
# 393  Tesla Q4 Deliveries Shy of Market Expectations...
#
# [394 rows x 4 columns]

# %%
# drop rows congruent with mod2 and mod3 
df_news = df_news.drop(df_news.index[[i for i in range(len(df_news)) if i % 2 == 0 or i % 3 == 0]])
df_news

# %%
# Cell 2 – Sentiment via Ollama + Qwen (headline-level)

import json
from typing import Any, Dict, Optional

try:
    import ollama  # pip install ollama
except ImportError:
    ollama = None
    print("Warning: 'ollama' is not installed. Run `pip install ollama` to use the sentiment functions.")


# Default model; override via env OLLAMA_MODEL if you like
import os
OLLAMA_MODEL = os.getenv("OLLAMA_MODEL", "gemma3:1b")
ticker = "TSLA"
name = "Tesla Inc."


SENTIMENT_SYSTEM_PROMPT = """\
You are a financial news sentiment analyst focusing on a single stock.

Given a short headline or short blurb about {name}. (ticker: {ticker}),
classify the sentiment with respect to {name}'s FUTURE stock performance as:

- "bullish": mainly positive impact on {ticker}
- "bearish": mainly negative impact on {ticker}
- "neutral": mixed or unclear impact, or {name} only mentioned tangentially

Return a compact JSON object with keys:
- "sentiment": one of ["bullish", "bearish", "neutral"]
- "score": a number between -1 and 1 (bearish=-1, bullish=1, neutral≈0)
- "confidence": number between 0 and 1
- "rationale": short explanation in English (1–3 sentences)

Respond with JSON only (no markdown, no backticks).
"""


def classify_headline_sentiment_ollama(
    text: str,
    *,
    model: str = OLLAMA_MODEL,
    max_chars: int = 800,
) -> Dict[str, Any]:
    """
    Classify sentiment of a short headline/blurb using a local Ollama model.

    Parameters
    ----------
    text : str
        Headline or very short summary.
    model : str
        Ollama model name (e.g. 'qwen3:4b').
    max_chars : int
        Max characters to send (just to be safe).

    Returns
    -------
    dict with keys:
        sentiment, score, confidence, rationale, raw
    where 'raw' is the raw model output (for debugging).
    """
    if ollama is None:
        raise RuntimeError("Ollama client not available. Install with `pip install ollama`.")

    snippet = (text or "").strip()
    if len(snippet) > max_chars:
        snippet = snippet[:max_chars] + "... [truncated]"

    user_payload = {
        "headline": snippet,
        "ticker": ticker,
    }

    user_text = (
        "Analyze the following headline about {name} ({ticker}).\n\n"
        + json.dumps(user_payload, ensure_ascii=False, indent=2)
        + "\n\nReturn only the JSON object as specified."
    )

    response = ollama.chat(
        model=model,
        messages=[
            {"role": "system", "content": SENTIMENT_SYSTEM_PROMPT},
            {"role": "user", "content": user_text},
        ],
    )
    raw = response["message"]["content"].strip()

    out: Dict[str, Any] = {
        "sentiment": None,
        "score": None,
        "confidence": None,
        "rationale": None,
        "raw": raw,
    }

    # Try robust JSON extraction: find first '{' and last '}'.
    try:
        start = raw.find("{")
        end = raw.rfind("}")
        if start != -1 and end != -1 and end > start:
            obj = json.loads(raw[start : end + 1])
        else:
            obj = json.loads(raw)

        out["sentiment"] = obj.get("sentiment")
        out["score"] = obj.get("score")
        out["confidence"] = obj.get("confidence")
        out["rationale"] = obj.get("rationale")
    except Exception as e:
        print(f"[classify_headline_sentiment_ollama] JSON parse error: {e}")

    return out


def score_news_df_with_ollama(
    df: pd.DataFrame,
    *,
    text_col: str = "body",
    model: str = OLLAMA_MODEL,
    limit: Optional[int] = None,
) -> pd.DataFrame:
    """
    Apply headline sentiment classification to a DataFrame.

    Parameters
    ----------
    df : DataFrame
        Must contain column `text_col` (e.g. 'body' or 'title').
    text_col : str
        Column used as input text to the model (we'll use 'body' by default).
    model : str
        Ollama model name.
    limit : Optional[int]
        If set, only the first `limit` rows are scored (for quick testing).

    Returns
    -------
    DataFrame : original df with additional columns:
        ['sentiment', 'sentiment_score', 'sentiment_confidence',
         'sentiment_rationale', 'sentiment_raw']
    """
    scored = df.copy()
    n = len(scored)
    if limit is not None:
        n = min(n, limit)

    sentiments: List[Dict[str, Any]] = []
    for i in range(n):
        text = str(scored.iloc[i][text_col])
        print(f"[score_news_df_with_ollama] {i+1}/{n}: {text[:90]}...")
        res = classify_headline_sentiment_ollama(text, model=model)
        sentiments.append(res)

    # For any remaining rows (if limit < len(df)), fill with None
    for _ in range(len(scored) - n):
        sentiments.append(
            {
                "sentiment": None,
                "score": None,
                "confidence": None,
                "rationale": None,
                "raw": None,
            }
        )

    scored["sentiment"] = [s.get("sentiment") for s in sentiments]
    scored["sentiment_score"] = [s.get("score") for s in sentiments]
    scored["sentiment_confidence"] = [s.get("confidence") for s in sentiments]
    scored["sentiment_rationale"] = [s.get("rationale") for s in sentiments]
    scored["sentiment_raw"] = [s.get("raw") for s in sentiments]

    return scored

#keep the first 5 rows for testing
df_scored_rag = score_news_df_with_ollama(df_news, limit=None)
df_scored_rag.to_csv("data/TSLA_sentiment.csv", index=False)
# Out:
# [score_news_df_with_ollama] 1/131: Sector Update: Consumer Stocks Fall Monday Afternoon...
# [score_news_df_with_ollama] 2/131: Morgan Stanley Downgrades Tesla to Equalweight From Overweight, Lifts Price Target to $425...
# [score_news_df_with_ollama] 3/131: BNP Paribas Raises Tesla Price Target to $313 From $307...
# [score_news_df_with_ollama] 4/131: Nvidia Sell-Off a 'DeepSeek Moment,' AI Revolution Just Beginning, Wedbush Says...
# [score_news_df_with_ollama] 5/131: Tesla AI Projects Face Uncertainty Despite Retention of Musk as CEO, Truist Says...
# [score_news_df_with_ollama] 6/131: Tesla Needs to Keep Elon Musk as CEO, Ives Says...
# [score_news_df_with_ollama] 7/131: TESLA : UBS remains a Sell rating...
# [score_news_df_with_ollama] 8/131: Tesla to See 'Overwhelming' Shareholder Support for Musk's Pay Package, xAI Investment, We...
# [score_news_df_with_ollama] 9/131: Deutsche Bank Adjusts Price Target on Tesla to $470 From $440, Maintains Buy Rating...
# [score_news_df_with_ollama] 10/131: President Capital Adjusts Price Target on Tesla to $529 From $373, Maintains Buy Rating...
# [score_news_df_with_ollama] 11/131: State Board of Administration of Florida supports proposed 2025 Tesla CEO's performance aw...
# [score_news_df_with_ollama] 12/131: China Renaissance Adjusts Price Target on Tesla to $380 From $349, Maintains Hold Rating...
# [score_news_df_with_ollama] 13/131: Musk's Pay Package Pulls Focus From Tesla Earnings...
# [score_news_df_with_ollama] 14/131: Tesla's Q3 Revenue Beat Driven by Strong Deliveries, Energy Storage Sales, Wedbush Says...
# [score_news_df_with_ollama] 15/131: TESLA : Deutsche Bank maintains a Buy rating...
# [score_news_df_with_ollama] 16/131: Deutsche Bank Adjusts Tesla Price Target to $440 From $435, Maintains Buy Rating...
# [score_news_df_with_ollama] 17/131: Cantor Fitzgerald Adjusts Price Target on Tesla to $510 From $355, Maintains Overweight Ra...
# [score_news_df_with_ollama] 18/131: Tech Earnings Solid After Lam, Tesla: Hedge Fund CIO...
# [score_news_df_with_ollama] 19/131: TESLA : Jefferies gives a Neutral rating...
# [score_news_df_with_ollama] 20/131: ROI-AI bubble isn't near a peak. It's only at 'base camp': Jen...
# [score_news_df_with_ollama] 21/131: Tech Up as Apple Rises on iPhone 17 Optimism -- Tech Roundup...
# [score_news_df_with_ollama] 22/131: Tesla Expected to Give 'Positive' EV Demand Commentary, Wedbush Says...
# [score_news_df_with_ollama] 23/131: Tech Up as Bubble Fears Ease - Tech Roundup...
# [score_news_df_with_ollama] 24/131: Global markets live: Blackstone, Pfizer, Tesla, Stellantis, AstraZeneca…...
# [score_news_df_with_ollama] 25/131: Tesla Could Capture 5% of $9 Trillion Humanoid Robot Market by 2050, RBC Says...
# [score_news_df_with_ollama] 26/131: Tesla CEO Musk to Earn 'Tens of Billions' From Pay Package Even if Most Goals Aren't Met...
# [score_news_df_with_ollama] 27/131: Analysts recommendations: Datadog, Alphabet, AMD, Elevance Health, Tesla…...
# [score_news_df_with_ollama] 28/131: TESLA : UBS gives a Sell rating...
# [score_news_df_with_ollama] 29/131: Wall Street eases from record highs on rising economic jitters...
# [score_news_df_with_ollama] 30/131: UBS Adjusts Tesla Price Target to $247 From $215, Maintains Sell Rating...
# [score_news_df_with_ollama] 31/131: JPMorgan Adjusts Tesla Price Target to $150 From $115...
# [score_news_df_with_ollama] 32/131: TESLA : RBC reiterates its Buy rating...
# [score_news_df_with_ollama] 33/131: Tesla's Sales Decline Expected to Slow in Delivery Report...
# [score_news_df_with_ollama] 34/131: Canaccord Genuity Adjusts Price Target on Tesla to $490 From $333, Maintains Buy Rating...
# [score_news_df_with_ollama] 35/131: TESLA : Receives a Buy rating from Deutsche Bank...
# [score_news_df_with_ollama] 36/131: Tesla Likely to Beat Third-Quarter Delivery Estimates Amid Stabilizing Global Demand, Wedb...
# [score_news_df_with_ollama] 37/131: Wedbush Adjusts Price Target on Tesla to $600 From $500, Maintains Outperform Rating...
# [score_news_df_with_ollama] 38/131: Mizuho Adjusts Price Target on Tesla to $450 From $375, Maintains Outperform Rating...
# [score_news_df_with_ollama] 39/131: Piper Sandler Adjusts Price Target on Tesla to $500 From $400, Maintains Overweight Rating...
# [score_news_df_with_ollama] 40/131: CICC Adjusts Price Target on Tesla to $450 From $360, Maintains Outperform Rating...
# [score_news_df_with_ollama] 41/131: The day the Fed resumed its rate cuts...
# [score_news_df_with_ollama] 42/131: Tesla's Proposed Incentive Package for Musk 'Smart Move' to Keep CEO Engaged at Critical J...
# [score_news_df_with_ollama] 43/131: Analyst recommendations: Apple, Tesla, Block, Eli Lilly, Fortinet…...
# [score_news_df_with_ollama] 44/131: TESLA : Deutsche Bank reiterates its Buy rating...
# [score_news_df_with_ollama] 45/131: Wall Street poised for higher open on US-EU deal optimism...
# [score_news_df_with_ollama] 46/131: Stifel Adjusts Price Target on Tesla to $440 From $450...
# [score_news_df_with_ollama] 47/131: China Renaissance Downgrades Tesla to Hold From Buy, Adjusts Price Target to $349 From $41...
# [score_news_df_with_ollama] 48/131: TESLA : Goldman Sachs reiterates its Neutral rating...
# [score_news_df_with_ollama] 49/131: TD Cowen Adjusts Price Target on Tesla to $374 From $330, Maintains Buy Rating...
# [score_news_df_with_ollama] 50/131: Canaccord Genuity Adjusts Price Target on Tesla to $333 From $303, Maintains Buy Rating...
# [score_news_df_with_ollama] 51/131: TESLA : RBC maintains a Buy rating...
# [score_news_df_with_ollama] 52/131: TESLA : BofA raises target price...
# [score_news_df_with_ollama] 53/131: BofA Securities Adjusts Price Target on Tesla to $341 From $305, Maintains Neutral Rating...
# [score_news_df_with_ollama] 54/131: Uber, Lyft Facing Disruption as Tesla Seeks to Expand Robotaxi Services, Wedbush Says...
# [score_news_df_with_ollama] 55/131: RBC Capital Adjusts Price Target on Tesla to $319 From $307, Maintains Outperform Rating...
# [score_news_df_with_ollama] 56/131: TESLA : Gets a Sell rating from JP Morgan...
# [score_news_df_with_ollama] 57/131: Tesla slides as Musk's 'America Party' heightens investor worries...
# [score_news_df_with_ollama] 58/131: TESLA : Gets a Buy rating from RBC...
# [score_news_df_with_ollama] 59/131: Global markets live: Wells Fargo, Apple, Intel, Greggs, Qantas Airways…...
# [score_news_df_with_ollama] 60/131: TESLA : Buy rating from RBC...
# [score_news_df_with_ollama] 61/131: China Renaissance Adjusts Price Target on Tesla to $410 From $367...
# [score_news_df_with_ollama] 62/131: TESLA : Sell rating from UBS...
# [score_news_df_with_ollama] 63/131: BNP Paribas Exane Adjusts Price Target on Tesla to $142 From $150...
# [score_news_df_with_ollama] 64/131: Argus Research Downgrades Tesla to Hold From Buy as Stock Trading at 'Non-Fundamental Even...
# [score_news_df_with_ollama] 65/131: Wall Street set to open higher as US-China trade talks begin...
# [score_news_df_with_ollama] 66/131: Analyst recommendations: Broadcom, Lululemon, McDonald's, Tesla, Etsy…...
# [score_news_df_with_ollama] 67/131: Wall Street stocks end down as Tesla slumps 14% on Trump-Musk feud...
# [score_news_df_with_ollama] 68/131: Wall Street dips as Tesla falls, investors focus on jobs data...
# [score_news_df_with_ollama] 69/131: Wall Street futures muted as investors await key jobs data...
# [score_news_df_with_ollama] 70/131: TESLA : Wedbush welcomes Elon Musk's departure from DOGE...
# [score_news_df_with_ollama] 71/131: Wedbush Ups Price Target on Tesla to $500 From $350 Highlighting Key Launch in June, Maint...
# [score_news_df_with_ollama] 72/131: Mizuho Adjusts Price Target on Tesla to $390 From $325, Maintains Outperform Rating...
# [score_news_df_with_ollama] 73/131: Analyst recommendations: Caterpillar, Chevron, Reddit, Tesla, United Airlines…...
# [score_news_df_with_ollama] 74/131: TESLA : UBS remains a Sell rating...
# [score_news_df_with_ollama] 75/131: Monolithic Power Systems Likely to See 'Modest Upside' to Q1 Results, Q2 Outlook, Oppenhei...
# [score_news_df_with_ollama] 76/131: China Renaissance Adjusts Price Target on Tesla to $367 From $429, Maintains Buy Rating...
# [score_news_df_with_ollama] 77/131: Analyst recommendations: Ge Aerospace, ServiceNow, Texas Instruments, AT&T, Tesla…...
# [score_news_df_with_ollama] 78/131: Investors relieved Musk will refocus on Tesla, but worry about brand damage...
# [score_news_df_with_ollama] 79/131: TESLA : JP Morgan reiterates its Sell rating...
# [score_news_df_with_ollama] 80/131: Roth Adjusts Price Target on Tesla to $395 From $450...
# [score_news_df_with_ollama] 81/131: Cantor Fitzgerald Adjusts Price Target on Tesla to $355 From $425, Keeps Overweight Rating...
# [score_news_df_with_ollama] 82/131: Baird Adjusts Price Target on Tesla to $320 From $370, Maintains Outperform Rating...
# [score_news_df_with_ollama] 83/131: Analyst recommendations: Amex, Chevron, Applovin, Hasbro, Tesla…...
# [score_news_df_with_ollama] 84/131: Fubon Securities Adjusts Price Target on Tesla to $470 From $764, Maintains Buy Rating...
# [score_news_df_with_ollama] 85/131: Goldman Sachs Adjusts Price Target on Tesla to $235 From $260, Maintains Neutral Rating...
# [score_news_df_with_ollama] 86/131: BofA Securities Adjusts Price Target on Tesla to $305 From $380, Maintains Neutral Rating...
# [score_news_df_with_ollama] 87/131: BNP Paribas Exane Adjusts Price Target on Tesla to $137 From $150, Keeps Underperform Rati...
# [score_news_df_with_ollama] 88/131: RBC Capital Adjusts Price Target on Tesla to $314 From $320, Keeps Outperform Rating...
# [score_news_df_with_ollama] 89/131: Mizuho Adjusts Price Target on Tesla to $375 From $430, Keeps Outperform Rating...
# [score_news_df_with_ollama] 90/131: TESLA : a double whammy Wedbush says...
# [score_news_df_with_ollama] 91/131: TESLA : Gets a Sell rating from JP Morgan...
# [score_news_df_with_ollama] 92/131: Goldman Sachs Adjusts Price Target on Tesla to $275 From $320, Maintains Neutral Rating...
# [score_news_df_with_ollama] 93/131: TESLA : UBS reiterates its Sell rating...
# [score_news_df_with_ollama] 94/131: TESLA : Deutsche Bank gives a Buy rating...
# [score_news_df_with_ollama] 95/131: TESLA : RBC gives a Buy rating...
# [score_news_df_with_ollama] 96/131: Tesla's Q1 Deliveries Expected to Be Weak Due to Demand Softness, Wedbush Securities Says...
# [score_news_df_with_ollama] 97/131: Daiwa Securities Adjusts Price Target on Tesla to $300 From $420, Keeps Neutral Rating...
# [score_news_df_with_ollama] 98/131: Piper Sandler Adjusts Price Target on Tesla to $450 From $500, Maintains Overweight Rating...
# [score_news_df_with_ollama] 99/131: Cantor Fitzgerald Upgrades Tesla to Overweight From Neutral, Price Target is $425...
# [score_news_df_with_ollama] 100/131: RBC Capital Adjusts Price Target on Tesla to $320 From $440, Keeps Outperform Rating...
# [score_news_df_with_ollama] 101/131: Mizuho Adjusts Price Target on Tesla to $430 From $515, Keeps Outperform Rating...
# [score_news_df_with_ollama] 102/131: JPMorgan Adjusts Tesla Price Target to $120 From $135...
# [score_news_df_with_ollama] 103/131: Evercore ISI Adjusts Price Target on Tesla to $235 From $275, Maintains In Line Rating...
# [score_news_df_with_ollama] 104/131: Tesla's Musk Has to Step Up as CEO Amid 'Brewing Political Firestorm,' Wedbush Says...
# [score_news_df_with_ollama] 105/131: Analyst recommendations: Ford, Tesla, ServiceNow, Rio Tinto, FedEx…...
# [score_news_df_with_ollama] 106/131: Baird Adjusts Price Target on Tesla to $370 From $440, Maintains Outperform Rating...
# [score_news_df_with_ollama] 107/131: Analyst recommendations: Booking, Marvell, Target, Dell, Tesla......
# [score_news_df_with_ollama] 108/131: Tesla rises 2% as Morgan Stanley backs AI, robotics efforts with 'top pick' status...
# [score_news_df_with_ollama] 109/131: TESLA : Receives a Buy rating from RBC...
# [score_news_df_with_ollama] 110/131: CICC Adjusts Price Target on Tesla to $425 From $300, Keeps Outperform Rating...
# [score_news_df_with_ollama] 111/131: The glass is always half full...
# [score_news_df_with_ollama] 112/131: President Capital Adjusts Price Target on Tesla to $426 From $278, Maintains Buy Rating...
# [score_news_df_with_ollama] 113/131: China Renaissance Adjusts Price Target on Tesla to $429 From $270, Keeps Buy Rating...
# [score_news_df_with_ollama] 114/131: Analysts recommendations: Alphabet, Cava Group, Cigna, Spotify, Tesla......
# [score_news_df_with_ollama] 115/131: TESLA : RBC reiterates its Buy rating...
# [score_news_df_with_ollama] 116/131: TESLA : Deutsche Bank reaffirms its Buy rating...
# [score_news_df_with_ollama] 117/131: Tesla's Q4 Results Excluding Bitcoin Gain 'Weaker Than Expected,' BofA Says...
# [score_news_df_with_ollama] 118/131: Cantor Fitzgerald Adjusts Price Target on Tesla to $425 From $365, Maintains Neutral Ratin...
# [score_news_df_with_ollama] 119/131: Truist Securities Adjusts Price Target on Tesla to $373 From $351, Keeps Hold Rating...
# [score_news_df_with_ollama] 120/131: TESLA : Jefferies remains Neutral...
# [score_news_df_with_ollama] 121/131: TESLA : UBS remains a Sell rating...
# [score_news_df_with_ollama] 122/131: Wedbush Raises Tesla's Price Target to $550 From $515, Keeps Outperform Rating...
# [score_news_df_with_ollama] 123/131: Piper Sandler Adjusts Price Target on Tesla to $500 From $315, Maintains Overweight Rating...
# [score_news_df_with_ollama] 124/131: Analyst recommendations: Adobe, Intuit, XPO, Netflix, Tesla......
# [score_news_df_with_ollama] 125/131: Tesla's Edge in AI, Mobility Backs Leadership Potential in Autonomous Rideshare Market, Mo...
# [score_news_df_with_ollama] 126/131: BNP Paribas Exane Adjusts Tesla's Price Target to $157 From $155, Keeps Underperform Ratin...
# [score_news_df_with_ollama] 127/131: BofA Downgrades Tesla to Neutral From Buy...
# [score_news_df_with_ollama] 128/131: Tesla: on the rebound with broker's comments...
# [score_news_df_with_ollama] 129/131: TESLA : price target raised at Canaccord...
# [score_news_df_with_ollama] 130/131: TESLA : RBC reaffirms its Buy rating...
# [score_news_df_with_ollama] 131/131: TESLA : Jefferies reiterates its Neutral rating...

# %%
df_scored_rag
# Out:
#                                                  title date_raw source_code  \
# 1    Sector Update: Consumer Stocks Fall Monday Aft...  Dec. 08          MT
# 5    Morgan Stanley Downgrades Tesla to Equalweight...  Dec. 08          MT
# 7    BNP Paribas Raises Tesla Price Target to $313 ...  Dec. 01          MT
# 11   Nvidia Sell-Off a 'DeepSeek Moment,' AI Revolu...  Nov. 21          MT
# 13   Tesla AI Projects Face Uncertainty Despite Ret...  Nov. 10          MT
# ..                                                 ...      ...         ...
# 379          BofA Downgrades Tesla to Neutral From Buy  Jan. 07          MT
# 383       Tesla: on the rebound with broker's comments  Jan. 03  Zonebourse
# 385           TESLA : price target raised at Canaccord  Jan. 03  Zonebourse
# 389               TESLA : RBC reaffirms its Buy rating  Jan. 02          ZD
# 391    TESLA : Jefferies reiterates its Neutral rating  Jan. 02          ZD
#
#                                                   body sentiment  \
# 1    Sector Update: Consumer Stocks Fall Monday Aft...   bearish
# 5    Morgan Stanley Downgrades Tesla to Equalweight...   bearish
# 7    BNP Paribas Raises Tesla Price Target to $313 ...   bullish
# 11   Nvidia Sell-Off a 'DeepSeek Moment,' AI Revolu...   bearish
# 13   Tesla AI Projects Face Uncertainty Despite Ret...   bearish
# ..                                                 ...       ...
# 379          BofA Downgrades Tesla to Neutral From Buy   bearish
# 383       Tesla: on the rebound with broker's comments   bullish
# 385           TESLA : price target raised at Canaccord   bearish
# 389               TESLA : RBC reaffirms its Buy rating   bullish
# 391    TESLA : Jefferies reiterates its Neutral rating   neutral
#
#      sentiment_score  sentiment_confidence  \
# 1               -0.6                   0.8
# 5               -0.8                   0.7
# 7                0.8                   0.9
# 11              -0.8                   0.7
# 13              -0.6                   0.8
# ..               ...                   ...
# 379             -0.8                   0.7
# 383              0.7                   0.8
# 385             -0.8                   0.7
# 389              0.7                   0.9
# 391              0.2                   0.9
#
#                                    sentiment_rationale  \
# 1    The headline indicates a decline in consumer s...
# 5    Downgrades from overweight to equalweight sugg...
# 7    The headline indicates a price increase for Te...
# 11   The headline explicitly mentions a sell-off, i...
# 13   The headline highlights potential challenges t...
# ..                                                 ...
# 379  The downgrade from buy by Bank of America sugg...
# 383  The headline explicitly mentions 'broker's com...
# 385  The headline indicates a raised price target s...
# 389  The phrase 'reaffirms its Buy rating' suggests...
# 391  The headline indicates a reassessment of Tesla...
#
#                                          sentiment_raw
# 1    ```json\n{\n  "sentiment": "bearish",\n  "scor...
# 5    ```json\n{\n  "sentiment": "bearish",\n  "scor...
# 7    ```json\n{\n  "sentiment": "bullish",\n  "scor...
# 11   ```json\n{\n  "sentiment": "bearish",\n  "scor...
# 13   ```json\n{\n  "sentiment": "bearish",\n  "scor...
# ..                                                 ...
# 379  ```json\n{\n  "sentiment": "bearish",\n  "scor...
# 383  ```json\n{\n  "sentiment": "bullish",\n  "scor...
# 385  ```json\n{\n  "sentiment": "bearish",\n  "scor...
# 389  ```json\n{\n  "sentiment": "bullish",\n  "scor...
# 391  ```json\n{\n  "sentiment": "neutral",\n  "scor...
#
# [131 rows x 9 columns]
