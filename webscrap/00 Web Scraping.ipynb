# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import time
from IPython.display import display, HTML

pd.set_option('display.max_rows', None)

def extraer_noticias_finviz(tick="TSLA") -> pd.DataFrame:
    """
    Extrae las noticias de un ticker de Finviz.
    Args:
        tick (str): Ticker de la acción a consultar.
    Returns:
        pd.DataFrame: DataFrame con las noticias, con fecha, título y URL.
    """

    url = f"https://finviz.com/quote.ashx?t={tick}&p=d"
    headers = {
        "User-Agent": (
            "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 "
            "(KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
        )
    }

    response = requests.get(url, headers=headers)

    if response.status_code != 200:
        raise Exception(f"Error al obtener la página: {response.status_code}")

    soup = BeautifulSoup(response.text, "html.parser")
    news_table = soup.find("table", class_="fullview-news-outer")

    noticias = []

    if news_table:
        rows = news_table.find_all("tr")
        for row in rows:
            cols = row.find_all("td")
            if len(cols) < 2:
                continue

            fecha = cols[0].text.strip()
            link_tag = cols[1].find("a")
            titulo = link_tag.text.strip() if link_tag else ""
            url = link_tag['href'] if link_tag and 'href' in link_tag.attrs else ""

            noticias.append({"fecha": fecha, "título": titulo, "url": url})

    df = pd.DataFrame(noticias)

    # Para los links que empiezan con '/news/', agregar el dominio finviz.com
    df['url'] = np.where(
        df['url'].str.startswith('/news/'),
        'https://finviz.com' + df['url'],
        df['url']
    )

    return df









def nombre_bonito(url):
    # Pone bonito el dominio de la URL, es para saber cuantas veces se repite un dominio en el DataFrame de noticias
    if "https://www." in url:
        url = url.replace("https://www.", "")
    elif "https://finance." in url:
        url = url.replace("https://finance.", "")
    elif "https://finviz.com/" in url:
        url = "finviz"
    elif "https://chainstoreage." in url:
        url = url.replace("https://chainstoreage.", "chainstoreage.")

    elif "https://seekingalpha." in url:
        url = url.replace("https://seekingalpha.", "seekingalpha.")

    elif "https://qz." in url:
        url = url.replace("https://qz.", "qz.")

    return url.split(".")[0]








def hiperreferenciar_titulos(df: pd.DataFrame) -> pd.DataFrame:
    """
    Agrega hiperenlaces a los títulos de las noticias en el DataFrame.
    Args:
        df (pd.DataFrame): DataFrame con las noticias.
    Returns:
        pd.DataFrame: DataFrame con los títulos convertidos en hiperenlaces.
    """

    if 'url' not in df.columns or 'título' not in df.columns:
        raise ValueError(
            "El DataFrame debe contener las columnas 'url' y 'título'.")

    df['título'] = df.apply(
        lambda row: f'<a href="{row["url"]}" target="_blank">{row["título"]}</a>' if row["url"] else row["título"],
        axis=1
    )

    return df







# Metodo
def web_scrap(tickers: list) -> dict:
    """
    Obtiene los datos de noticias para una lista de tickers de acciones.
    Utiliza la función `extraer_noticias_finviz` para cada ticker y maneja errores de conexión.
    Esta función espera 10 segundos entre cada solicitud para evitar el error 429 (Too Many Requests).
    Args:
        tickers (list): Lista de tickers de acciones a consultar.
    Returns:
        dict: Diccionario donde las claves son los tickers y los valores son DataFrames con las noticias.
    Raises:
        Exception: Si ocurre un error al extraer las noticias para un ticker, se espera 10 segundos y se reintenta.
    """

    dfs = {}
    for tick in tickers:
        try:
            dfs[tick] = extraer_noticias_finviz(tick)
            print(f"{tick} ya!")
        except Exception as e:
            print(f"Tenemos que esperar un poco más para {tick}: {e}")
            time.sleep(10) 
            dfs[tick] = extraer_noticias_finviz(tick)
            print(f"{tick} ya!")

    return dfs





# Metodo
def cuantas_veces(dfs: dict, tick: str, index = False) -> pd.DataFrame:
    """
    Cuenta cuántas veces aparece cada journal en las noticias de un ticker y lo muestra como DataFrame.
    Args:
        dfs (dict): Diccionario de DataFrames de noticias por ticker.
        tick (str): Ticker de la acción a consultar.
    index (bool): Si es True, muestra el índice del DataFrame. Por defecto es False.
    Returns:
        pd.DataFrame: DataFrame con el conteo de cada journal.
    """

    df = dfs[tick]
    conteo = df["url"].apply(nombre_bonito).value_counts().reset_index()
    conteo.columns = ['journal', 'veces']

    display(HTML(f'<h2 style="text-align:left;">Últimas 100 noticias de {tick}</h2>'))

    if index:
        display(conteo.style.set_properties(subset=['journal'], **{'text-align': 'left'})
               .set_properties(subset=['veces'], **{'text-align': 'right'})
               .set_table_styles([{'selector': 'th', 'props': [('text-align', 'center')]}]))
    else:
        display(conteo.style.hide(axis="index"))
    
    return None



# Metodo
def cuantas_veces_todos(dfs: dict, index = False) -> None:
    for tick, df in dfs.items():
        cuantas_veces(dfs, tick, index=index)






def agrupar_journals(df: pd.DataFrame, journals: list) -> None:
    """
    Agrega los datos de noticias de diferentes journals al DataFrame total.
    Args:
        dfs (pd.DataFrame): DataFrame con las noticias.
        journals (list): Lista de nombres de journals a filtrar.
    """
    
    # Generalizar para cualquier lista de journals
    dftotal = pd.DataFrame(columns=df.columns)
    fila_vacia = pd.DataFrame([{col: "" for col in df.columns}])

    for journal in journals:
        # Filtrar por journal
        df_journal = df[df['url'].str.contains(journal, case=False, na=False)]
        # Fila con el nombre del journal
        fila_nombre = fila_vacia.copy()
        fila_vacia['fecha'] = "---"
        fila_nombre['título'] = journal
        # Concatenar: nombre, noticias, fila vacía
        dftotal = pd.concat([dftotal, fila_vacia, fila_nombre, df_journal], ignore_index=True)
    
    return dftotal



def highlight_fila_nombre(row, journals):
    if row['título'] in journals:
        return ['font-weight: bold'] * len(row)
    else:
        return [''] * len(row)
    




def quiero_ver(tick: str, journals: list, dfs: dict, index = False) -> None:
    """
    Muestra las noticias de un ticker específico y los journals seleccionados.
    Args:
        tick (str): Ticker de la acción a consultar.
        journals (list): Lista de nombres de journals a filtrar.
        dfs (dict): Diccionario de DataFrames de noticias por ticker.
        index (bool): Si es True, muestra el índice del DataFrame. Por defecto es False.
    Returns:
        None: Muestra las noticias en un formato HTML estilizado.
    Raises:
        ValueError: Si el ticker no se encuentra en el diccionario de DataFrames.
    """
    dftotal = agrupar_journals(dfs[tick], journals)
    dftotal = hiperreferenciar_titulos(dftotal)
    display(HTML(f'<h2 style="text-align:left;">Noticias de {tick}</h2>'))

    if index:
        display(
            dftotal.drop(columns=['url'])
            .style
            .apply(lambda row: highlight_fila_nombre(row, journals), axis=1)
            .set_properties(subset=['fecha'], **{'text-align': 'right'})
            .set_properties(subset=['título'], **{'text-align': 'left'})
            .set_table_styles([{'selector': 'th', 'props': [('text-align', 'center')]}])
        )
    else:
        display(
            dftotal.drop(columns=['url'])
            .style
            .hide(axis="index")
            .apply(lambda row: highlight_fila_nombre(row, journals), axis=1)
            .set_properties(subset=['fecha'], **{'text-align': 'right'})
            .set_properties(subset=['título'], **{'text-align': 'left'})
            .set_table_styles([{'selector': 'th', 'props': [('text-align', 'center')]}])
        )
    
    return None

def quiero_ver_todos(journals, dfs, index = False) -> None:
    """    Muestra las noticias de todos los tickers para los journals seleccionados.
    """
    for tick, df in dfs.items():
        quiero_ver(tick, journals, dfs, index=index)

# %%
tickers = [
    "TSLA", "NKE", "MSFT", "NVDA", "AAPL", "AMZN", "GOOG", "GOOGL", "META",
]

# %%
dfs = web_scrap(tickers)
# Out:
# TSLA ya!
# NKE ya!
# MSFT ya!
# NVDA ya!
# AAPL ya!
# AMZN ya!
# GOOG ya!
# GOOGL ya!
# META ya!

# %% [markdown]
# # **Para un ticker**

# %%
cuantas_veces(dfs, "TSLA")
# Out:
# <h2 style="text-align:left;">Últimas 100 noticias de TSLA</h2>
# <style type="text/css">
# </style>
# <table id="T_84d53">
#   <thead>
#     <tr>
#       <th id="T_84d53_level0_col0" class="col_heading level0 col0" >journal</th>
#       <th id="T_84d53_level0_col1" class="col_heading level0 col1" >veces</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_84d53_row0_col0" class="data row0 col0" >yahoo</td>
#       <td id="T_84d53_row0_col1" class="data row0 col1" >57</td>
#     </tr>
#     <tr>
#       <td id="T_84d53_row1_col0" class="data row1 col0" >finviz</td>
#       <td id="T_84d53_row1_col1" class="data row1 col1" >20</td>
#     </tr>
#     <tr>
#       <td id="T_84d53_row2_col0" class="data row2 col0" >barrons</td>
#       <td id="T_84d53_row2_col1" class="data row2 col1" >13</td>
#     </tr>
#     <tr>
#       <td id="T_84d53_row3_col0" class="data row3 col0" >investors</td>
#       <td id="T_84d53_row3_col1" class="data row3 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_84d53_row4_col0" class="data row4 col0" >marketwatch</td>
#       <td id="T_84d53_row4_col1" class="data row4 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_84d53_row5_col0" class="data row5 col0" >youtube</td>
#       <td id="T_84d53_row5_col1" class="data row5 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_84d53_row6_col0" class="data row6 col0" >wsj</td>
#       <td id="T_84d53_row6_col1" class="data row6 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_84d53_row7_col0" class="data row7 col0" >aboveavalon</td>
#       <td id="T_84d53_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_84d53_row8_col0" class="data row8 col0" >digitimes</td>
#       <td id="T_84d53_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
cuantas_veces(dfs, "TSLA", index=1)
# Out:
# <h2 style="text-align:left;">Últimas 100 noticias de TSLA</h2>
# <style type="text/css">
# #T_6430e th {
#   text-align: center;
# }
# #T_6430e_row0_col0, #T_6430e_row1_col0, #T_6430e_row2_col0, #T_6430e_row3_col0, #T_6430e_row4_col0, #T_6430e_row5_col0, #T_6430e_row6_col0, #T_6430e_row7_col0, #T_6430e_row8_col0 {
#   text-align: left;
# }
# #T_6430e_row0_col1, #T_6430e_row1_col1, #T_6430e_row2_col1, #T_6430e_row3_col1, #T_6430e_row4_col1, #T_6430e_row5_col1, #T_6430e_row6_col1, #T_6430e_row7_col1, #T_6430e_row8_col1 {
#   text-align: right;
# }
# </style>
# <table id="T_6430e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6430e_level0_col0" class="col_heading level0 col0" >journal</th>
#       <th id="T_6430e_level0_col1" class="col_heading level0 col1" >veces</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6430e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6430e_row0_col0" class="data row0 col0" >yahoo</td>
#       <td id="T_6430e_row0_col1" class="data row0 col1" >57</td>
#     </tr>
#     <tr>
#       <th id="T_6430e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6430e_row1_col0" class="data row1 col0" >finviz</td>
#       <td id="T_6430e_row1_col1" class="data row1 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_6430e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6430e_row2_col0" class="data row2 col0" >barrons</td>
#       <td id="T_6430e_row2_col1" class="data row2 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_6430e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6430e_row3_col0" class="data row3 col0" >investors</td>
#       <td id="T_6430e_row3_col1" class="data row3 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_6430e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6430e_row4_col0" class="data row4 col0" >marketwatch</td>
#       <td id="T_6430e_row4_col1" class="data row4 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_6430e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6430e_row5_col0" class="data row5 col0" >youtube</td>
#       <td id="T_6430e_row5_col1" class="data row5 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_6430e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6430e_row6_col0" class="data row6 col0" >wsj</td>
#       <td id="T_6430e_row6_col1" class="data row6 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6430e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6430e_row7_col0" class="data row7 col0" >aboveavalon</td>
#       <td id="T_6430e_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6430e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6430e_row8_col0" class="data row8 col0" >digitimes</td>
#       <td id="T_6430e_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
journals = ["wsj", "barrons"]

quiero_ver("TSLA", journals, dfs, index=1)
# Out:
# <h2 style="text-align:left;">Noticias de TSLA</h2>
# <style type="text/css">
# #T_14cb5 th {
#   text-align: center;
# }
# #T_14cb5_row0_col0, #T_14cb5_row2_col0, #T_14cb5_row3_col0, #T_14cb5_row5_col0, #T_14cb5_row6_col0, #T_14cb5_row7_col0, #T_14cb5_row8_col0, #T_14cb5_row9_col0, #T_14cb5_row10_col0, #T_14cb5_row11_col0, #T_14cb5_row12_col0, #T_14cb5_row13_col0, #T_14cb5_row14_col0, #T_14cb5_row15_col0, #T_14cb5_row16_col0, #T_14cb5_row17_col0 {
#   text-align: right;
# }
# #T_14cb5_row0_col1, #T_14cb5_row2_col1, #T_14cb5_row3_col1, #T_14cb5_row5_col1, #T_14cb5_row6_col1, #T_14cb5_row7_col1, #T_14cb5_row8_col1, #T_14cb5_row9_col1, #T_14cb5_row10_col1, #T_14cb5_row11_col1, #T_14cb5_row12_col1, #T_14cb5_row13_col1, #T_14cb5_row14_col1, #T_14cb5_row15_col1, #T_14cb5_row16_col1, #T_14cb5_row17_col1 {
#   text-align: left;
# }
# #T_14cb5_row1_col0, #T_14cb5_row4_col0 {
#   font-weight: bold;
#   text-align: right;
# }
# #T_14cb5_row1_col1, #T_14cb5_row4_col1 {
#   font-weight: bold;
#   text-align: left;
# }
# </style>
# <table id="T_14cb5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_14cb5_level0_col0" class="col_heading level0 col0" >fecha</th>
#       <th id="T_14cb5_level0_col1" class="col_heading level0 col1" >título</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14cb5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_14cb5_row0_col0" class="data row0 col0" >---</td>
#       <td id="T_14cb5_row0_col1" class="data row0 col1" ></td>
#     </tr>
#     <tr>
#       <th id="T_14cb5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_14cb5_row1_col0" class="data row1 col0" ></td>
#       <td id="T_14cb5_row1_col1" class="data row1 col1" >wsj</td>
#     </tr>
#     <tr>
#       <th id="T_14cb5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_14cb5_row2_col0" class="data row2 col0" >Dec-11-25 05:11PM</td>
#       <td id="T_14cb5_row2_col1" class="data row2 col1" ><a href="https://www.wsj.com/business/autos/rivian-autonomy-ai-day-hands-free-016a94e6?mod=wsj_FV" target="_blank">Rivian Expands Hands-Free Driving in AI Push</a></td>
#     </tr>
#     <tr>
#       <th id="T_14cb5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_14cb5_row3_col0" class="data row3 col0" >---</td>
#       <td id="T_14cb5_row3_col1" class="data row3 col1" ></td>
#     </tr>
#     <tr>
#       <th id="T_14cb5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_14cb5_row4_col0" class="data row4 col0" >---</td>
#       <td id="T_14cb5_row4_col1" class="data row4 col1" >barrons</td>
#     </tr>
#     <tr>
#       <th id="T_14cb5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_14cb5_row5_col0" class="data row5 col0" >05:08PM</td>
#       <td id="T_14cb5_row5_col1" class="data row5 col1" ><a href="https://www.barrons.com/articles/rivian-stock-ai-tesla-evs-e79f6f16?mod=bar_FV" target="_blank">Rivian Went Full Tesla, With One Exception. The Stock Dropped.</a></td>
#     </tr>
#     <tr>
#       <th id="T_14cb5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_14cb5_row6_col0" class="data row6 col0" >08:19AM</td>
#       <td id="T_14cb5_row6_col1" class="data row6 col1" ><a href="https://www.barrons.com/articles/tesla-stock-price-robo-taxis-e5aabcbb?mod=bar_FV" target="_blank">Tesla Stock Slips. Analysts Are Split on Full-Self Driving Progress.</a></td>
#     </tr>
#     <tr>
#       <th id="T_14cb5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_14cb5_row7_col0" class="data row7 col0" >03:53PM</td>
#       <td id="T_14cb5_row7_col1" class="data row7 col1" ><a href="https://www.barrons.com/articles/powell-santa-claus-rally-ba1c1353?mod=bar_FV" target="_blank">Powell Gave Stock Markets the Present it Wanted. It Could Giftwrap the Santa Claus Rally.</a></td>
#     </tr>
#     <tr>
#       <th id="T_14cb5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_14cb5_row8_col0" class="data row8 col0" >07:45AM</td>
#       <td id="T_14cb5_row8_col1" class="data row8 col1" ><a href="https://www.barrons.com/articles/elon-musk-confirms-spacex-ipo-7515a12a?mod=bar_FV" target="_blank">Elon Musk Appears to Confirm SpaceX IPO. Here's What Could Happen Next.</a></td>
#     </tr>
#     <tr>
#       <th id="T_14cb5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_14cb5_row9_col0" class="data row9 col0" >07:14AM</td>
#       <td id="T_14cb5_row9_col1" class="data row9 col1" ><a href="https://www.barrons.com/articles/spacex-ipo-elon-musk-ai-7515a12a?mod=bar_FV" target="_blank">A SpaceX IPO Could Happen Soon. Here's What Elon Musk Says.</a></td>
#     </tr>
#     <tr>
#       <th id="T_14cb5_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_14cb5_row10_col0" class="data row10 col0" >08:13AM</td>
#       <td id="T_14cb5_row10_col1" class="data row10 col1" ><a href="https://www.barrons.com/articles/tesla-stock-price-deutsche-bank-top-pick-e1f561de?mod=bar_FV" target="_blank">Why Tesla Stock Is Deutsche Bank's Top Car Pick for 2026</a></td>
#     </tr>
#     <tr>
#       <th id="T_14cb5_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_14cb5_row11_col0" class="data row11 col0" >07:48AM</td>
#       <td id="T_14cb5_row11_col1" class="data row11 col1" ><a href="https://www.barrons.com/articles/tesla-stock-deutsche-bank-top-pick-e1f561de?mod=bar_FV" target="_blank">Tesla Stock Is This Bank's Top Pick. Why It Can Accelerate Into 2026 and Beyond.</a></td>
#     </tr>
#     <tr>
#       <th id="T_14cb5_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_14cb5_row12_col0" class="data row12 col0" >06:59AM</td>
#       <td id="T_14cb5_row12_col1" class="data row12 col1" ><a href="https://www.barrons.com/articles/spacex-ipo-tesla-stock-8e46370f?mod=bar_FV" target="_blank">What a SpaceX IPO Would Mean for Tesla Investors</a></td>
#     </tr>
#     <tr>
#       <th id="T_14cb5_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_14cb5_row13_col0" class="data row13 col0" >06:26AM</td>
#       <td id="T_14cb5_row13_col1" class="data row13 col1" ><a href="https://www.barrons.com/articles/fed-rate-cut-stock-market-things-to-know-today-d80aa5d3?mod=bar_FV" target="_blank">The Fed's Divided on Rates. Why Stock Markets Can Rise Through 2026 Anyway and 5 Other Things to Know Today.</a></td>
#     </tr>
#     <tr>
#       <th id="T_14cb5_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_14cb5_row14_col0" class="data row14 col0" >04:43PM</td>
#       <td id="T_14cb5_row14_col1" class="data row14 col1" ><a href="https://www.barrons.com/articles/exxon-stock-price-energy-demand-nextera-042b8ac5?mod=bar_FV" target="_blank">NextEra Sees a Golden Age for Power Demand-and Exxon Stock Could Gain</a></td>
#     </tr>
#     <tr>
#       <th id="T_14cb5_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_14cb5_row15_col0" class="data row15 col0" >04:37PM</td>
#       <td id="T_14cb5_row15_col1" class="data row15 col1" ><a href="https://www.barrons.com/articles/tesla-stock-price-china-ev-sales-ea9f7c0d?mod=bar_FV" target="_blank">Tesla China Sales Decline Again. Can It Salvage a Bad Year?</a></td>
#     </tr>
#     <tr>
#       <th id="T_14cb5_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_14cb5_row16_col0" class="data row16 col0" >02:47PM</td>
#       <td id="T_14cb5_row16_col1" class="data row16 col1" ><a href="https://www.barrons.com/articles/car-stocks-earnings-growth-13cd03e5?mod=bar_FV" target="_blank">The Car Market Is in Transition. 5 Stocks That Can Win in 2026.</a></td>
#     </tr>
#     <tr>
#       <th id="T_14cb5_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_14cb5_row17_col0" class="data row17 col0" >02:19PM</td>
#       <td id="T_14cb5_row17_col1" class="data row17 col1" ><a href="https://www.barrons.com/articles/cathie-wood-ark-invest-tesla-baidu-weride-stock-price-4514708b?mod=bar_FV" target="_blank">Cathie Wood's ARK Invest Sold Tesla Stock and Snapped Up These Chinese Tech Stocks</a></td>
#     </tr>
#   </tbody>
# </table>

# %%
quiero_ver("TSLA", journals, dfs)
# Out:
# <h2 style="text-align:left;">Noticias de TSLA</h2>
# <style type="text/css">
# #T_bc700 th {
#   text-align: center;
# }
# #T_bc700_row0_col0, #T_bc700_row2_col0, #T_bc700_row3_col0, #T_bc700_row5_col0, #T_bc700_row6_col0, #T_bc700_row7_col0, #T_bc700_row8_col0, #T_bc700_row9_col0, #T_bc700_row10_col0, #T_bc700_row11_col0, #T_bc700_row12_col0, #T_bc700_row13_col0, #T_bc700_row14_col0, #T_bc700_row15_col0, #T_bc700_row16_col0, #T_bc700_row17_col0 {
#   text-align: right;
# }
# #T_bc700_row0_col1, #T_bc700_row2_col1, #T_bc700_row3_col1, #T_bc700_row5_col1, #T_bc700_row6_col1, #T_bc700_row7_col1, #T_bc700_row8_col1, #T_bc700_row9_col1, #T_bc700_row10_col1, #T_bc700_row11_col1, #T_bc700_row12_col1, #T_bc700_row13_col1, #T_bc700_row14_col1, #T_bc700_row15_col1, #T_bc700_row16_col1, #T_bc700_row17_col1 {
#   text-align: left;
# }
# #T_bc700_row1_col0, #T_bc700_row4_col0 {
#   font-weight: bold;
#   text-align: right;
# }
# #T_bc700_row1_col1, #T_bc700_row4_col1 {
#   font-weight: bold;
#   text-align: left;
# }
# </style>
# <table id="T_bc700">
#   <thead>
#     <tr>
#       <th id="T_bc700_level0_col0" class="col_heading level0 col0" >fecha</th>
#       <th id="T_bc700_level0_col1" class="col_heading level0 col1" >título</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_bc700_row0_col0" class="data row0 col0" >---</td>
#       <td id="T_bc700_row0_col1" class="data row0 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_bc700_row1_col0" class="data row1 col0" ></td>
#       <td id="T_bc700_row1_col1" class="data row1 col1" >wsj</td>
#     </tr>
#     <tr>
#       <td id="T_bc700_row2_col0" class="data row2 col0" >Dec-11-25 05:11PM</td>
#       <td id="T_bc700_row2_col1" class="data row2 col1" ><a href="https://www.wsj.com/business/autos/rivian-autonomy-ai-day-hands-free-016a94e6?mod=wsj_FV" target="_blank">Rivian Expands Hands-Free Driving in AI Push</a></td>
#     </tr>
#     <tr>
#       <td id="T_bc700_row3_col0" class="data row3 col0" >---</td>
#       <td id="T_bc700_row3_col1" class="data row3 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_bc700_row4_col0" class="data row4 col0" >---</td>
#       <td id="T_bc700_row4_col1" class="data row4 col1" >barrons</td>
#     </tr>
#     <tr>
#       <td id="T_bc700_row5_col0" class="data row5 col0" >05:08PM</td>
#       <td id="T_bc700_row5_col1" class="data row5 col1" ><a href="https://www.barrons.com/articles/rivian-stock-ai-tesla-evs-e79f6f16?mod=bar_FV" target="_blank">Rivian Went Full Tesla, With One Exception. The Stock Dropped.</a></td>
#     </tr>
#     <tr>
#       <td id="T_bc700_row6_col0" class="data row6 col0" >08:19AM</td>
#       <td id="T_bc700_row6_col1" class="data row6 col1" ><a href="https://www.barrons.com/articles/tesla-stock-price-robo-taxis-e5aabcbb?mod=bar_FV" target="_blank">Tesla Stock Slips. Analysts Are Split on Full-Self Driving Progress.</a></td>
#     </tr>
#     <tr>
#       <td id="T_bc700_row7_col0" class="data row7 col0" >03:53PM</td>
#       <td id="T_bc700_row7_col1" class="data row7 col1" ><a href="https://www.barrons.com/articles/powell-santa-claus-rally-ba1c1353?mod=bar_FV" target="_blank">Powell Gave Stock Markets the Present it Wanted. It Could Giftwrap the Santa Claus Rally.</a></td>
#     </tr>
#     <tr>
#       <td id="T_bc700_row8_col0" class="data row8 col0" >07:45AM</td>
#       <td id="T_bc700_row8_col1" class="data row8 col1" ><a href="https://www.barrons.com/articles/elon-musk-confirms-spacex-ipo-7515a12a?mod=bar_FV" target="_blank">Elon Musk Appears to Confirm SpaceX IPO. Here's What Could Happen Next.</a></td>
#     </tr>
#     <tr>
#       <td id="T_bc700_row9_col0" class="data row9 col0" >07:14AM</td>
#       <td id="T_bc700_row9_col1" class="data row9 col1" ><a href="https://www.barrons.com/articles/spacex-ipo-elon-musk-ai-7515a12a?mod=bar_FV" target="_blank">A SpaceX IPO Could Happen Soon. Here's What Elon Musk Says.</a></td>
#     </tr>
#     <tr>
#       <td id="T_bc700_row10_col0" class="data row10 col0" >08:13AM</td>
#       <td id="T_bc700_row10_col1" class="data row10 col1" ><a href="https://www.barrons.com/articles/tesla-stock-price-deutsche-bank-top-pick-e1f561de?mod=bar_FV" target="_blank">Why Tesla Stock Is Deutsche Bank's Top Car Pick for 2026</a></td>
#     </tr>
#     <tr>
#       <td id="T_bc700_row11_col0" class="data row11 col0" >07:48AM</td>
#       <td id="T_bc700_row11_col1" class="data row11 col1" ><a href="https://www.barrons.com/articles/tesla-stock-deutsche-bank-top-pick-e1f561de?mod=bar_FV" target="_blank">Tesla Stock Is This Bank's Top Pick. Why It Can Accelerate Into 2026 and Beyond.</a></td>
#     </tr>
#     <tr>
#       <td id="T_bc700_row12_col0" class="data row12 col0" >06:59AM</td>
#       <td id="T_bc700_row12_col1" class="data row12 col1" ><a href="https://www.barrons.com/articles/spacex-ipo-tesla-stock-8e46370f?mod=bar_FV" target="_blank">What a SpaceX IPO Would Mean for Tesla Investors</a></td>
#     </tr>
#     <tr>
#       <td id="T_bc700_row13_col0" class="data row13 col0" >06:26AM</td>
#       <td id="T_bc700_row13_col1" class="data row13 col1" ><a href="https://www.barrons.com/articles/fed-rate-cut-stock-market-things-to-know-today-d80aa5d3?mod=bar_FV" target="_blank">The Fed's Divided on Rates. Why Stock Markets Can Rise Through 2026 Anyway and 5 Other Things to Know Today.</a></td>
#     </tr>
#     <tr>
#       <td id="T_bc700_row14_col0" class="data row14 col0" >04:43PM</td>
#       <td id="T_bc700_row14_col1" class="data row14 col1" ><a href="https://www.barrons.com/articles/exxon-stock-price-energy-demand-nextera-042b8ac5?mod=bar_FV" target="_blank">NextEra Sees a Golden Age for Power Demand-and Exxon Stock Could Gain</a></td>
#     </tr>
#     <tr>
#       <td id="T_bc700_row15_col0" class="data row15 col0" >04:37PM</td>
#       <td id="T_bc700_row15_col1" class="data row15 col1" ><a href="https://www.barrons.com/articles/tesla-stock-price-china-ev-sales-ea9f7c0d?mod=bar_FV" target="_blank">Tesla China Sales Decline Again. Can It Salvage a Bad Year?</a></td>
#     </tr>
#     <tr>
#       <td id="T_bc700_row16_col0" class="data row16 col0" >02:47PM</td>
#       <td id="T_bc700_row16_col1" class="data row16 col1" ><a href="https://www.barrons.com/articles/car-stocks-earnings-growth-13cd03e5?mod=bar_FV" target="_blank">The Car Market Is in Transition. 5 Stocks That Can Win in 2026.</a></td>
#     </tr>
#     <tr>
#       <td id="T_bc700_row17_col0" class="data row17 col0" >02:19PM</td>
#       <td id="T_bc700_row17_col1" class="data row17 col1" ><a href="https://www.barrons.com/articles/cathie-wood-ark-invest-tesla-baidu-weride-stock-price-4514708b?mod=bar_FV" target="_blank">Cathie Wood's ARK Invest Sold Tesla Stock and Snapped Up These Chinese Tech Stocks</a></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # **Para todos los tickers**

# %%
cuantas_veces_todos(dfs)
# Out:
# <h2 style="text-align:left;">Últimas 100 noticias de TSLA</h2>
# <style type="text/css">
# </style>
# <table id="T_aec65">
#   <thead>
#     <tr>
#       <th id="T_aec65_level0_col0" class="col_heading level0 col0" >journal</th>
#       <th id="T_aec65_level0_col1" class="col_heading level0 col1" >veces</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_aec65_row0_col0" class="data row0 col0" >yahoo</td>
#       <td id="T_aec65_row0_col1" class="data row0 col1" >57</td>
#     </tr>
#     <tr>
#       <td id="T_aec65_row1_col0" class="data row1 col0" >finviz</td>
#       <td id="T_aec65_row1_col1" class="data row1 col1" >20</td>
#     </tr>
#     <tr>
#       <td id="T_aec65_row2_col0" class="data row2 col0" >barrons</td>
#       <td id="T_aec65_row2_col1" class="data row2 col1" >13</td>
#     </tr>
#     <tr>
#       <td id="T_aec65_row3_col0" class="data row3 col0" >investors</td>
#       <td id="T_aec65_row3_col1" class="data row3 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_aec65_row4_col0" class="data row4 col0" >marketwatch</td>
#       <td id="T_aec65_row4_col1" class="data row4 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_aec65_row5_col0" class="data row5 col0" >youtube</td>
#       <td id="T_aec65_row5_col1" class="data row5 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_aec65_row6_col0" class="data row6 col0" >wsj</td>
#       <td id="T_aec65_row6_col1" class="data row6 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_aec65_row7_col0" class="data row7 col0" >aboveavalon</td>
#       <td id="T_aec65_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_aec65_row8_col0" class="data row8 col0" >digitimes</td>
#       <td id="T_aec65_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#   </tbody>
# </table>
# <h2 style="text-align:left;">Últimas 100 noticias de NKE</h2>
# <style type="text/css">
# </style>
# <table id="T_9cb55">
#   <thead>
#     <tr>
#       <th id="T_9cb55_level0_col0" class="col_heading level0 col0" >journal</th>
#       <th id="T_9cb55_level0_col1" class="col_heading level0 col1" >veces</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9cb55_row0_col0" class="data row0 col0" >yahoo</td>
#       <td id="T_9cb55_row0_col1" class="data row0 col1" >55</td>
#     </tr>
#     <tr>
#       <td id="T_9cb55_row1_col0" class="data row1 col0" >finviz</td>
#       <td id="T_9cb55_row1_col1" class="data row1 col1" >34</td>
#     </tr>
#     <tr>
#       <td id="T_9cb55_row2_col0" class="data row2 col0" >wsj</td>
#       <td id="T_9cb55_row2_col1" class="data row2 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_9cb55_row3_col0" class="data row3 col0" >businesswire</td>
#       <td id="T_9cb55_row3_col1" class="data row3 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_9cb55_row4_col0" class="data row4 col0" >marketwatch</td>
#       <td id="T_9cb55_row4_col1" class="data row4 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_9cb55_row5_col0" class="data row5 col0" >barrons</td>
#       <td id="T_9cb55_row5_col1" class="data row5 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_9cb55_row6_col0" class="data row6 col0" >youtube</td>
#       <td id="T_9cb55_row6_col1" class="data row6 col1" >1</td>
#     </tr>
#   </tbody>
# </table>
# <h2 style="text-align:left;">Últimas 100 noticias de MSFT</h2>
# <style type="text/css">
# </style>
# <table id="T_7de1d">
#   <thead>
#     <tr>
#       <th id="T_7de1d_level0_col0" class="col_heading level0 col0" >journal</th>
#       <th id="T_7de1d_level0_col1" class="col_heading level0 col1" >veces</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7de1d_row0_col0" class="data row0 col0" >yahoo</td>
#       <td id="T_7de1d_row0_col1" class="data row0 col1" >60</td>
#     </tr>
#     <tr>
#       <td id="T_7de1d_row1_col0" class="data row1 col0" >finviz</td>
#       <td id="T_7de1d_row1_col1" class="data row1 col1" >25</td>
#     </tr>
#     <tr>
#       <td id="T_7de1d_row2_col0" class="data row2 col0" >barrons</td>
#       <td id="T_7de1d_row2_col1" class="data row2 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_7de1d_row3_col0" class="data row3 col0" >marketwatch</td>
#       <td id="T_7de1d_row3_col1" class="data row3 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_7de1d_row4_col0" class="data row4 col0" >youtube</td>
#       <td id="T_7de1d_row4_col1" class="data row4 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_7de1d_row5_col0" class="data row5 col0" >digitimes</td>
#       <td id="T_7de1d_row5_col1" class="data row5 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_7de1d_row6_col0" class="data row6 col0" >investors</td>
#       <td id="T_7de1d_row6_col1" class="data row6 col1" >1</td>
#     </tr>
#   </tbody>
# </table>
# <h2 style="text-align:left;">Últimas 100 noticias de NVDA</h2>
# <style type="text/css">
# </style>
# <table id="T_0dc49">
#   <thead>
#     <tr>
#       <th id="T_0dc49_level0_col0" class="col_heading level0 col0" >journal</th>
#       <th id="T_0dc49_level0_col1" class="col_heading level0 col1" >veces</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0dc49_row0_col0" class="data row0 col0" >yahoo</td>
#       <td id="T_0dc49_row0_col1" class="data row0 col1" >51</td>
#     </tr>
#     <tr>
#       <td id="T_0dc49_row1_col0" class="data row1 col0" >finviz</td>
#       <td id="T_0dc49_row1_col1" class="data row1 col1" >31</td>
#     </tr>
#     <tr>
#       <td id="T_0dc49_row2_col0" class="data row2 col0" >barrons</td>
#       <td id="T_0dc49_row2_col1" class="data row2 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_0dc49_row3_col0" class="data row3 col0" >marketwatch</td>
#       <td id="T_0dc49_row3_col1" class="data row3 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_0dc49_row4_col0" class="data row4 col0" >digitimes</td>
#       <td id="T_0dc49_row4_col1" class="data row4 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_0dc49_row5_col0" class="data row5 col0" >wsj</td>
#       <td id="T_0dc49_row5_col1" class="data row5 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_0dc49_row6_col0" class="data row6 col0" >youtube</td>
#       <td id="T_0dc49_row6_col1" class="data row6 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_0dc49_row7_col0" class="data row7 col0" >investors</td>
#       <td id="T_0dc49_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#   </tbody>
# </table>
# <h2 style="text-align:left;">Últimas 100 noticias de AAPL</h2>
# <style type="text/css">
# </style>
# <table id="T_faac5">
#   <thead>
#     <tr>
#       <th id="T_faac5_level0_col0" class="col_heading level0 col0" >journal</th>
#       <th id="T_faac5_level0_col1" class="col_heading level0 col1" >veces</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_faac5_row0_col0" class="data row0 col0" >yahoo</td>
#       <td id="T_faac5_row0_col1" class="data row0 col1" >60</td>
#     </tr>
#     <tr>
#       <td id="T_faac5_row1_col0" class="data row1 col0" >finviz</td>
#       <td id="T_faac5_row1_col1" class="data row1 col1" >19</td>
#     </tr>
#     <tr>
#       <td id="T_faac5_row2_col0" class="data row2 col0" >barrons</td>
#       <td id="T_faac5_row2_col1" class="data row2 col1" >6</td>
#     </tr>
#     <tr>
#       <td id="T_faac5_row3_col0" class="data row3 col0" >youtube</td>
#       <td id="T_faac5_row3_col1" class="data row3 col1" >5</td>
#     </tr>
#     <tr>
#       <td id="T_faac5_row4_col0" class="data row4 col0" >aboveavalon</td>
#       <td id="T_faac5_row4_col1" class="data row4 col1" >4</td>
#     </tr>
#     <tr>
#       <td id="T_faac5_row5_col0" class="data row5 col0" >digitimes</td>
#       <td id="T_faac5_row5_col1" class="data row5 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_faac5_row6_col0" class="data row6 col0" >investors</td>
#       <td id="T_faac5_row6_col1" class="data row6 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_faac5_row7_col0" class="data row7 col0" >wsj</td>
#       <td id="T_faac5_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_faac5_row8_col0" class="data row8 col0" >marketwatch</td>
#       <td id="T_faac5_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#   </tbody>
# </table>
# <h2 style="text-align:left;">Últimas 100 noticias de AMZN</h2>
# <style type="text/css">
# </style>
# <table id="T_31662">
#   <thead>
#     <tr>
#       <th id="T_31662_level0_col0" class="col_heading level0 col0" >journal</th>
#       <th id="T_31662_level0_col1" class="col_heading level0 col1" >veces</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_31662_row0_col0" class="data row0 col0" >yahoo</td>
#       <td id="T_31662_row0_col1" class="data row0 col1" >62</td>
#     </tr>
#     <tr>
#       <td id="T_31662_row1_col0" class="data row1 col0" >finviz</td>
#       <td id="T_31662_row1_col1" class="data row1 col1" >26</td>
#     </tr>
#     <tr>
#       <td id="T_31662_row2_col0" class="data row2 col0" >barrons</td>
#       <td id="T_31662_row2_col1" class="data row2 col1" >7</td>
#     </tr>
#     <tr>
#       <td id="T_31662_row3_col0" class="data row3 col0" >marketwatch</td>
#       <td id="T_31662_row3_col1" class="data row3 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_31662_row4_col0" class="data row4 col0" >investors</td>
#       <td id="T_31662_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_31662_row5_col0" class="data row5 col0" >digitimes</td>
#       <td id="T_31662_row5_col1" class="data row5 col1" >1</td>
#     </tr>
#   </tbody>
# </table>
# <h2 style="text-align:left;">Últimas 100 noticias de GOOG</h2>
# <style type="text/css">
# </style>
# <table id="T_b0b68">
#   <thead>
#     <tr>
#       <th id="T_b0b68_level0_col0" class="col_heading level0 col0" >journal</th>
#       <th id="T_b0b68_level0_col1" class="col_heading level0 col1" >veces</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b0b68_row0_col0" class="data row0 col0" >yahoo</td>
#       <td id="T_b0b68_row0_col1" class="data row0 col1" >71</td>
#     </tr>
#     <tr>
#       <td id="T_b0b68_row1_col0" class="data row1 col0" >finviz</td>
#       <td id="T_b0b68_row1_col1" class="data row1 col1" >19</td>
#     </tr>
#     <tr>
#       <td id="T_b0b68_row2_col0" class="data row2 col0" >youtube</td>
#       <td id="T_b0b68_row2_col1" class="data row2 col1" >5</td>
#     </tr>
#     <tr>
#       <td id="T_b0b68_row3_col0" class="data row3 col0" >marketwatch</td>
#       <td id="T_b0b68_row3_col1" class="data row3 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_b0b68_row4_col0" class="data row4 col0" >digitimes</td>
#       <td id="T_b0b68_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_b0b68_row5_col0" class="data row5 col0" >qz</td>
#       <td id="T_b0b68_row5_col1" class="data row5 col1" >1</td>
#     </tr>
#   </tbody>
# </table>
# <h2 style="text-align:left;">Últimas 100 noticias de GOOGL</h2>
# <style type="text/css">
# </style>
# <table id="T_103f5">
#   <thead>
#     <tr>
#       <th id="T_103f5_level0_col0" class="col_heading level0 col0" >journal</th>
#       <th id="T_103f5_level0_col1" class="col_heading level0 col1" >veces</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_103f5_row0_col0" class="data row0 col0" >yahoo</td>
#       <td id="T_103f5_row0_col1" class="data row0 col1" >58</td>
#     </tr>
#     <tr>
#       <td id="T_103f5_row1_col0" class="data row1 col0" >finviz</td>
#       <td id="T_103f5_row1_col1" class="data row1 col1" >26</td>
#     </tr>
#     <tr>
#       <td id="T_103f5_row2_col0" class="data row2 col0" >marketwatch</td>
#       <td id="T_103f5_row2_col1" class="data row2 col1" >6</td>
#     </tr>
#     <tr>
#       <td id="T_103f5_row3_col0" class="data row3 col0" >youtube</td>
#       <td id="T_103f5_row3_col1" class="data row3 col1" >5</td>
#     </tr>
#     <tr>
#       <td id="T_103f5_row4_col0" class="data row4 col0" >barrons</td>
#       <td id="T_103f5_row4_col1" class="data row4 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_103f5_row5_col0" class="data row5 col0" >digitimes</td>
#       <td id="T_103f5_row5_col1" class="data row5 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_103f5_row6_col0" class="data row6 col0" >qz</td>
#       <td id="T_103f5_row6_col1" class="data row6 col1" >1</td>
#     </tr>
#   </tbody>
# </table>
# <h2 style="text-align:left;">Últimas 100 noticias de META</h2>
# <style type="text/css">
# </style>
# <table id="T_6a5b6">
#   <thead>
#     <tr>
#       <th id="T_6a5b6_level0_col0" class="col_heading level0 col0" >journal</th>
#       <th id="T_6a5b6_level0_col1" class="col_heading level0 col1" >veces</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6a5b6_row0_col0" class="data row0 col0" >yahoo</td>
#       <td id="T_6a5b6_row0_col1" class="data row0 col1" >73</td>
#     </tr>
#     <tr>
#       <td id="T_6a5b6_row1_col0" class="data row1 col0" >finviz</td>
#       <td id="T_6a5b6_row1_col1" class="data row1 col1" >14</td>
#     </tr>
#     <tr>
#       <td id="T_6a5b6_row2_col0" class="data row2 col0" >barrons</td>
#       <td id="T_6a5b6_row2_col1" class="data row2 col1" >5</td>
#     </tr>
#     <tr>
#       <td id="T_6a5b6_row3_col0" class="data row3 col0" >marketwatch</td>
#       <td id="T_6a5b6_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <td id="T_6a5b6_row4_col0" class="data row4 col0" >youtube</td>
#       <td id="T_6a5b6_row4_col1" class="data row4 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_6a5b6_row5_col0" class="data row5 col0" >investors</td>
#       <td id="T_6a5b6_row5_col1" class="data row5 col1" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
quiero_ver_todos(journals, dfs)
# Out:
# <h2 style="text-align:left;">Noticias de TSLA</h2>
# <style type="text/css">
# #T_afc21 th {
#   text-align: center;
# }
# #T_afc21_row0_col0, #T_afc21_row2_col0, #T_afc21_row3_col0, #T_afc21_row5_col0, #T_afc21_row6_col0, #T_afc21_row7_col0, #T_afc21_row8_col0, #T_afc21_row9_col0, #T_afc21_row10_col0, #T_afc21_row11_col0, #T_afc21_row12_col0, #T_afc21_row13_col0, #T_afc21_row14_col0, #T_afc21_row15_col0, #T_afc21_row16_col0, #T_afc21_row17_col0 {
#   text-align: right;
# }
# #T_afc21_row0_col1, #T_afc21_row2_col1, #T_afc21_row3_col1, #T_afc21_row5_col1, #T_afc21_row6_col1, #T_afc21_row7_col1, #T_afc21_row8_col1, #T_afc21_row9_col1, #T_afc21_row10_col1, #T_afc21_row11_col1, #T_afc21_row12_col1, #T_afc21_row13_col1, #T_afc21_row14_col1, #T_afc21_row15_col1, #T_afc21_row16_col1, #T_afc21_row17_col1 {
#   text-align: left;
# }
# #T_afc21_row1_col0, #T_afc21_row4_col0 {
#   font-weight: bold;
#   text-align: right;
# }
# #T_afc21_row1_col1, #T_afc21_row4_col1 {
#   font-weight: bold;
#   text-align: left;
# }
# </style>
# <table id="T_afc21">
#   <thead>
#     <tr>
#       <th id="T_afc21_level0_col0" class="col_heading level0 col0" >fecha</th>
#       <th id="T_afc21_level0_col1" class="col_heading level0 col1" >título</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_afc21_row0_col0" class="data row0 col0" >---</td>
#       <td id="T_afc21_row0_col1" class="data row0 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_afc21_row1_col0" class="data row1 col0" ></td>
#       <td id="T_afc21_row1_col1" class="data row1 col1" >wsj</td>
#     </tr>
#     <tr>
#       <td id="T_afc21_row2_col0" class="data row2 col0" >Dec-11-25 05:11PM</td>
#       <td id="T_afc21_row2_col1" class="data row2 col1" ><a href="https://www.wsj.com/business/autos/rivian-autonomy-ai-day-hands-free-016a94e6?mod=wsj_FV" target="_blank">Rivian Expands Hands-Free Driving in AI Push</a></td>
#     </tr>
#     <tr>
#       <td id="T_afc21_row3_col0" class="data row3 col0" >---</td>
#       <td id="T_afc21_row3_col1" class="data row3 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_afc21_row4_col0" class="data row4 col0" >---</td>
#       <td id="T_afc21_row4_col1" class="data row4 col1" >barrons</td>
#     </tr>
#     <tr>
#       <td id="T_afc21_row5_col0" class="data row5 col0" >05:08PM</td>
#       <td id="T_afc21_row5_col1" class="data row5 col1" ><a href="https://www.barrons.com/articles/rivian-stock-ai-tesla-evs-e79f6f16?mod=bar_FV" target="_blank">Rivian Went Full Tesla, With One Exception. The Stock Dropped.</a></td>
#     </tr>
#     <tr>
#       <td id="T_afc21_row6_col0" class="data row6 col0" >08:19AM</td>
#       <td id="T_afc21_row6_col1" class="data row6 col1" ><a href="https://www.barrons.com/articles/tesla-stock-price-robo-taxis-e5aabcbb?mod=bar_FV" target="_blank">Tesla Stock Slips. Analysts Are Split on Full-Self Driving Progress.</a></td>
#     </tr>
#     <tr>
#       <td id="T_afc21_row7_col0" class="data row7 col0" >03:53PM</td>
#       <td id="T_afc21_row7_col1" class="data row7 col1" ><a href="https://www.barrons.com/articles/powell-santa-claus-rally-ba1c1353?mod=bar_FV" target="_blank">Powell Gave Stock Markets the Present it Wanted. It Could Giftwrap the Santa Claus Rally.</a></td>
#     </tr>
#     <tr>
#       <td id="T_afc21_row8_col0" class="data row8 col0" >07:45AM</td>
#       <td id="T_afc21_row8_col1" class="data row8 col1" ><a href="https://www.barrons.com/articles/elon-musk-confirms-spacex-ipo-7515a12a?mod=bar_FV" target="_blank">Elon Musk Appears to Confirm SpaceX IPO. Here's What Could Happen Next.</a></td>
#     </tr>
#     <tr>
#       <td id="T_afc21_row9_col0" class="data row9 col0" >07:14AM</td>
#       <td id="T_afc21_row9_col1" class="data row9 col1" ><a href="https://www.barrons.com/articles/spacex-ipo-elon-musk-ai-7515a12a?mod=bar_FV" target="_blank">A SpaceX IPO Could Happen Soon. Here's What Elon Musk Says.</a></td>
#     </tr>
#     <tr>
#       <td id="T_afc21_row10_col0" class="data row10 col0" >08:13AM</td>
#       <td id="T_afc21_row10_col1" class="data row10 col1" ><a href="https://www.barrons.com/articles/tesla-stock-price-deutsche-bank-top-pick-e1f561de?mod=bar_FV" target="_blank">Why Tesla Stock Is Deutsche Bank's Top Car Pick for 2026</a></td>
#     </tr>
#     <tr>
#       <td id="T_afc21_row11_col0" class="data row11 col0" >07:48AM</td>
#       <td id="T_afc21_row11_col1" class="data row11 col1" ><a href="https://www.barrons.com/articles/tesla-stock-deutsche-bank-top-pick-e1f561de?mod=bar_FV" target="_blank">Tesla Stock Is This Bank's Top Pick. Why It Can Accelerate Into 2026 and Beyond.</a></td>
#     </tr>
#     <tr>
#       <td id="T_afc21_row12_col0" class="data row12 col0" >06:59AM</td>
#       <td id="T_afc21_row12_col1" class="data row12 col1" ><a href="https://www.barrons.com/articles/spacex-ipo-tesla-stock-8e46370f?mod=bar_FV" target="_blank">What a SpaceX IPO Would Mean for Tesla Investors</a></td>
#     </tr>
#     <tr>
#       <td id="T_afc21_row13_col0" class="data row13 col0" >06:26AM</td>
#       <td id="T_afc21_row13_col1" class="data row13 col1" ><a href="https://www.barrons.com/articles/fed-rate-cut-stock-market-things-to-know-today-d80aa5d3?mod=bar_FV" target="_blank">The Fed's Divided on Rates. Why Stock Markets Can Rise Through 2026 Anyway and 5 Other Things to Know Today.</a></td>
#     </tr>
#     <tr>
#       <td id="T_afc21_row14_col0" class="data row14 col0" >04:43PM</td>
#       <td id="T_afc21_row14_col1" class="data row14 col1" ><a href="https://www.barrons.com/articles/exxon-stock-price-energy-demand-nextera-042b8ac5?mod=bar_FV" target="_blank">NextEra Sees a Golden Age for Power Demand-and Exxon Stock Could Gain</a></td>
#     </tr>
#     <tr>
#       <td id="T_afc21_row15_col0" class="data row15 col0" >04:37PM</td>
#       <td id="T_afc21_row15_col1" class="data row15 col1" ><a href="https://www.barrons.com/articles/tesla-stock-price-china-ev-sales-ea9f7c0d?mod=bar_FV" target="_blank">Tesla China Sales Decline Again. Can It Salvage a Bad Year?</a></td>
#     </tr>
#     <tr>
#       <td id="T_afc21_row16_col0" class="data row16 col0" >02:47PM</td>
#       <td id="T_afc21_row16_col1" class="data row16 col1" ><a href="https://www.barrons.com/articles/car-stocks-earnings-growth-13cd03e5?mod=bar_FV" target="_blank">The Car Market Is in Transition. 5 Stocks That Can Win in 2026.</a></td>
#     </tr>
#     <tr>
#       <td id="T_afc21_row17_col0" class="data row17 col0" >02:19PM</td>
#       <td id="T_afc21_row17_col1" class="data row17 col1" ><a href="https://www.barrons.com/articles/cathie-wood-ark-invest-tesla-baidu-weride-stock-price-4514708b?mod=bar_FV" target="_blank">Cathie Wood's ARK Invest Sold Tesla Stock and Snapped Up These Chinese Tech Stocks</a></td>
#     </tr>
#   </tbody>
# </table>
# <h2 style="text-align:left;">Noticias de NKE</h2>
# <style type="text/css">
# #T_4af8e th {
#   text-align: center;
# }
# #T_4af8e_row0_col0, #T_4af8e_row2_col0, #T_4af8e_row3_col0, #T_4af8e_row4_col0, #T_4af8e_row5_col0, #T_4af8e_row7_col0, #T_4af8e_row8_col0 {
#   text-align: right;
# }
# #T_4af8e_row0_col1, #T_4af8e_row2_col1, #T_4af8e_row3_col1, #T_4af8e_row4_col1, #T_4af8e_row5_col1, #T_4af8e_row7_col1, #T_4af8e_row8_col1 {
#   text-align: left;
# }
# #T_4af8e_row1_col0, #T_4af8e_row6_col0 {
#   font-weight: bold;
#   text-align: right;
# }
# #T_4af8e_row1_col1, #T_4af8e_row6_col1 {
#   font-weight: bold;
#   text-align: left;
# }
# </style>
# <table id="T_4af8e">
#   <thead>
#     <tr>
#       <th id="T_4af8e_level0_col0" class="col_heading level0 col0" >fecha</th>
#       <th id="T_4af8e_level0_col1" class="col_heading level0 col1" >título</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4af8e_row0_col0" class="data row0 col0" >---</td>
#       <td id="T_4af8e_row0_col1" class="data row0 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_4af8e_row1_col0" class="data row1 col0" ></td>
#       <td id="T_4af8e_row1_col1" class="data row1 col1" >wsj</td>
#     </tr>
#     <tr>
#       <td id="T_4af8e_row2_col0" class="data row2 col0" >09:37AM</td>
#       <td id="T_4af8e_row2_col1" class="data row2 col1" ><a href="https://www.wsj.com/livecoverage/stock-market-today-dow-sp-500-nasdaq-12-03-2025/card/stocks-to-watch-wednesday-marvell-crowdstrike-dollar-tree-GaGMb6KmSL2X5JC2Nqml?mod=wsj_FV" target="_blank">Stocks to Watch Wednesday: Royal Bank of Canada, CrowdStrike, Dollar Tree</a></td>
#     </tr>
#     <tr>
#       <td id="T_4af8e_row3_col0" class="data row3 col0" >Dec-02-25 05:59PM</td>
#       <td id="T_4af8e_row3_col1" class="data row3 col1" ><a href="https://www.wsj.com/business/retail/nike-shakes-up-leadership-team-as-turnaround-plan-continues-e80ac242?mod=wsj_FV" target="_blank">Nike Shakes Up Leadership Team as Turnaround Plan Continues</a></td>
#     </tr>
#     <tr>
#       <td id="T_4af8e_row4_col0" class="data row4 col0" >12:00PM</td>
#       <td id="T_4af8e_row4_col1" class="data row4 col1" ><a href="https://www.wsj.com/business/retail/nike-ceo-on-companys-reinvention-plan-af11fa1d?mod=wsj_FV" target="_blank">Nike CEO on Company's Reinvention Plan</a></td>
#     </tr>
#     <tr>
#       <td id="T_4af8e_row5_col0" class="data row5 col0" >---</td>
#       <td id="T_4af8e_row5_col1" class="data row5 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_4af8e_row6_col0" class="data row6 col0" >---</td>
#       <td id="T_4af8e_row6_col1" class="data row6 col1" >barrons</td>
#     </tr>
#     <tr>
#       <td id="T_4af8e_row7_col0" class="data row7 col0" >11:35AM</td>
#       <td id="T_4af8e_row7_col1" class="data row7 col1" ><a href="https://www.barrons.com/articles/al-gore-nike-toast-salesforce-tsm-stock-624e64e7?mod=bar_FV" target="_blank">What Stocks Al Gore's Investment Firm Bought and Sold This Quarter</a></td>
#     </tr>
#     <tr>
#       <td id="T_4af8e_row8_col0" class="data row8 col0" >02:00AM</td>
#       <td id="T_4af8e_row8_col1" class="data row8 col1" ><a href="https://www.barrons.com/articles/on-stock-sneaker-tariff-problem-jumps-e5d19f69?mod=bar_FV" target="_blank">On Stock Doesn't Have a Tariff Problem After All</a></td>
#     </tr>
#   </tbody>
# </table>
# <h2 style="text-align:left;">Noticias de MSFT</h2>
# <style type="text/css">
# #T_b18ed th {
#   text-align: center;
# }
# #T_b18ed_row0_col0, #T_b18ed_row2_col0, #T_b18ed_row4_col0, #T_b18ed_row5_col0, #T_b18ed_row6_col0, #T_b18ed_row7_col0, #T_b18ed_row8_col0, #T_b18ed_row9_col0, #T_b18ed_row10_col0, #T_b18ed_row11_col0 {
#   text-align: right;
# }
# #T_b18ed_row0_col1, #T_b18ed_row2_col1, #T_b18ed_row4_col1, #T_b18ed_row5_col1, #T_b18ed_row6_col1, #T_b18ed_row7_col1, #T_b18ed_row8_col1, #T_b18ed_row9_col1, #T_b18ed_row10_col1, #T_b18ed_row11_col1 {
#   text-align: left;
# }
# #T_b18ed_row1_col0, #T_b18ed_row3_col0 {
#   font-weight: bold;
#   text-align: right;
# }
# #T_b18ed_row1_col1, #T_b18ed_row3_col1 {
#   font-weight: bold;
#   text-align: left;
# }
# </style>
# <table id="T_b18ed">
#   <thead>
#     <tr>
#       <th id="T_b18ed_level0_col0" class="col_heading level0 col0" >fecha</th>
#       <th id="T_b18ed_level0_col1" class="col_heading level0 col1" >título</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b18ed_row0_col0" class="data row0 col0" >---</td>
#       <td id="T_b18ed_row0_col1" class="data row0 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_b18ed_row1_col0" class="data row1 col0" ></td>
#       <td id="T_b18ed_row1_col1" class="data row1 col1" >wsj</td>
#     </tr>
#     <tr>
#       <td id="T_b18ed_row2_col0" class="data row2 col0" >---</td>
#       <td id="T_b18ed_row2_col1" class="data row2 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_b18ed_row3_col0" class="data row3 col0" >---</td>
#       <td id="T_b18ed_row3_col1" class="data row3 col1" >barrons</td>
#     </tr>
#     <tr>
#       <td id="T_b18ed_row4_col0" class="data row4 col0" >07:22AM</td>
#       <td id="T_b18ed_row4_col1" class="data row4 col1" ><a href="https://www.barrons.com/articles/oracle-stock-earnings-federal-reserve-rate-cut-b67e85c6?mod=bar_FV" target="_blank">Oracle and the Fed Were Expected to Provide Wall Street With Answers. Only One Delivered.</a></td>
#     </tr>
#     <tr>
#       <td id="T_b18ed_row5_col0" class="data row5 col0" >02:00AM</td>
#       <td id="T_b18ed_row5_col1" class="data row5 col1" ><a href="https://www.barrons.com/articles/microsoft-broadcom-lilly-stocks-f036c3cc?mod=bar_FV" target="_blank">Microsoft, Broadcom, Lilly, and Other Stocks That Meet This Pro's Definition of 'Quality'</a></td>
#     </tr>
#     <tr>
#       <td id="T_b18ed_row6_col0" class="data row6 col0" >04:46PM</td>
#       <td id="T_b18ed_row6_col1" class="data row6 col1" ><a href="https://www.barrons.com/articles/best-tech-stocks-to-buy-now-2026-dac5ca73?mod=bar_FV" target="_blank">The 3 Best Tech Stocks to Buy for 2026, According to Our Columnist</a></td>
#     </tr>
#     <tr>
#       <td id="T_b18ed_row7_col0" class="data row7 col0" >09:30AM</td>
#       <td id="T_b18ed_row7_col1" class="data row7 col1" ><a href="https://www.barrons.com/articles/small-cap-stocks-s-p500-17241392?mod=bar_FV" target="_blank">Small-Cap Stocks May Be Ready to Outperform After Five Years of Lagging</a></td>
#     </tr>
#     <tr>
#       <td id="T_b18ed_row8_col0" class="data row8 col0" >07:35AM</td>
#       <td id="T_b18ed_row8_col1" class="data row8 col1" ><a href="https://www.barrons.com/articles/marvell-stock-chips-microsoft-amazon-9ea60f11?mod=bar_FV" target="_blank">Marvell Stock Falls on Microsoft, Amazon Fears. 'Block Out the Noise.'</a></td>
#     </tr>
#     <tr>
#       <td id="T_b18ed_row9_col0" class="data row9 col0" >02:30AM</td>
#       <td id="T_b18ed_row9_col1" class="data row9 col1" ><a href="https://www.barrons.com/articles/oracle-earnings-stock-price-9c6a3454?mod=bar_FV" target="_blank">Oracle Earnings Face Pressing Questions About OpenAI and Profit Margins</a></td>
#     </tr>
#     <tr>
#       <td id="T_b18ed_row10_col0" class="data row10 col0" >03:48PM</td>
#       <td id="T_b18ed_row10_col1" class="data row10 col1" ><a href="https://www.barrons.com/articles/tech-stocks-buy-ai-meta-47d11a3a?mod=bar_FV" target="_blank">2 Reasons Tech Stocks Are Rise Past AI Worries</a></td>
#     </tr>
#     <tr>
#       <td id="T_b18ed_row11_col0" class="data row11 col0" >02:00PM</td>
#       <td id="T_b18ed_row11_col1" class="data row11 col1" ><a href="https://www.barrons.com/articles/meta-stock-price-tech-ai-buy-47d11a3a?mod=bar_FV" target="_blank">2 Reasons Meta and Other Tech Stocks Can Rise Past AI Worries</a></td>
#     </tr>
#   </tbody>
# </table>
# <h2 style="text-align:left;">Noticias de NVDA</h2>
# <style type="text/css">
# #T_aab08 th {
#   text-align: center;
# }
# #T_aab08_row0_col0, #T_aab08_row2_col0, #T_aab08_row3_col0, #T_aab08_row4_col0, #T_aab08_row6_col0, #T_aab08_row7_col0, #T_aab08_row8_col0, #T_aab08_row9_col0, #T_aab08_row10_col0, #T_aab08_row11_col0, #T_aab08_row12_col0, #T_aab08_row13_col0 {
#   text-align: right;
# }
# #T_aab08_row0_col1, #T_aab08_row2_col1, #T_aab08_row3_col1, #T_aab08_row4_col1, #T_aab08_row6_col1, #T_aab08_row7_col1, #T_aab08_row8_col1, #T_aab08_row9_col1, #T_aab08_row10_col1, #T_aab08_row11_col1, #T_aab08_row12_col1, #T_aab08_row13_col1 {
#   text-align: left;
# }
# #T_aab08_row1_col0, #T_aab08_row5_col0 {
#   font-weight: bold;
#   text-align: right;
# }
# #T_aab08_row1_col1, #T_aab08_row5_col1 {
#   font-weight: bold;
#   text-align: left;
# }
# </style>
# <table id="T_aab08">
#   <thead>
#     <tr>
#       <th id="T_aab08_level0_col0" class="col_heading level0 col0" >fecha</th>
#       <th id="T_aab08_level0_col1" class="col_heading level0 col1" >título</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_aab08_row0_col0" class="data row0 col0" >---</td>
#       <td id="T_aab08_row0_col1" class="data row0 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_aab08_row1_col0" class="data row1 col0" ></td>
#       <td id="T_aab08_row1_col1" class="data row1 col1" >wsj</td>
#     </tr>
#     <tr>
#       <td id="T_aab08_row2_col0" class="data row2 col0" >11:18AM</td>
#       <td id="T_aab08_row2_col1" class="data row2 col1" ><a href="https://www.wsj.com/livecoverage/stock-market-today-dow-sp-500-nasdaq-12-11-2025/card/oracle-adobe-broadcom-ai-related-earnings-in-spotlight-g55IYMXp0iicy6b7QTmV?mod=wsj_FV" target="_blank">Oracle, Adobe, Broadcom: AI-Related Earnings in Spotlight</a></td>
#     </tr>
#     <tr>
#       <td id="T_aab08_row3_col0" class="data row3 col0" >09:38AM</td>
#       <td id="T_aab08_row3_col1" class="data row3 col1" ><a href="https://www.wsj.com/livecoverage/stock-market-today-dow-sp-500-nasdaq-12-11-2025/card/stocks-to-watch-thursday-oracle-broadcom-nvidia-WruGTUKTH1wPKYZ7SXAu?mod=wsj_FV" target="_blank">Stocks to Watch Thursday: Oracle, Broadcom, Gemini Space Station</a></td>
#     </tr>
#     <tr>
#       <td id="T_aab08_row4_col0" class="data row4 col0" >---</td>
#       <td id="T_aab08_row4_col1" class="data row4 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_aab08_row5_col0" class="data row5 col0" >---</td>
#       <td id="T_aab08_row5_col1" class="data row5 col1" >barrons</td>
#     </tr>
#     <tr>
#       <td id="T_aab08_row6_col0" class="data row6 col0" >10:05AM</td>
#       <td id="T_aab08_row6_col1" class="data row6 col1" ><a href="https://www.barrons.com/articles/ai-stock-trade-oracle-earnings-nvidia-5654cc26?mod=bar_FV" target="_blank">The AI Trade Is Tanking as Anxieties Reemerge</a></td>
#     </tr>
#     <tr>
#       <td id="T_aab08_row7_col0" class="data row7 col0" >07:32AM</td>
#       <td id="T_aab08_row7_col1" class="data row7 col1" ><a href="https://www.barrons.com/articles/nvidia-stock-price-oracle-37493727?mod=bar_FV" target="_blank">Nvidia Stock Falls. 2 Reasons Oracle's Earnings Were Bad for the Chip Maker.</a></td>
#     </tr>
#     <tr>
#       <td id="T_aab08_row8_col0" class="data row8 col0" >07:22AM</td>
#       <td id="T_aab08_row8_col1" class="data row8 col1" ><a href="https://www.barrons.com/articles/oracle-stock-earnings-federal-reserve-rate-cut-b67e85c6?mod=bar_FV" target="_blank">Oracle and the Fed Were Expected to Provide Wall Street With Answers. Only One Delivered.</a></td>
#     </tr>
#     <tr>
#       <td id="T_aab08_row9_col0" class="data row9 col0" >06:27AM</td>
#       <td id="T_aab08_row9_col1" class="data row9 col1" ><a href="https://www.barrons.com/articles/stock-market-buy-the-dip-strategy-c05a2f5c?mod=bar_FV" target="_blank">Buy Stocks on the Dip? Here's a Better Strategy.</a></td>
#     </tr>
#     <tr>
#       <td id="T_aab08_row10_col0" class="data row10 col0" >05:08AM</td>
#       <td id="T_aab08_row10_col1" class="data row10 col1" ><a href="https://www.barrons.com/articles/stock-movers-b842b5d9?mod=bar_FV" target="_blank">These Stocks Are Moving the Most Today: Oracle, Nvidia, Adobe, Synopsys, Oxford Industries, Gemini, and More.</a></td>
#     </tr>
#     <tr>
#       <td id="T_aab08_row11_col0" class="data row11 col0" >05:02PM</td>
#       <td id="T_aab08_row11_col1" class="data row11 col1" ><a href="https://www.barrons.com/articles/synopsys-stock-earnings-price-39d9b277?mod=bar_FV" target="_blank">Synopsys Stock Rises on Earnings Beat, Higher Guidance</a></td>
#     </tr>
#     <tr>
#       <td id="T_aab08_row12_col0" class="data row12 col0" >04:46PM</td>
#       <td id="T_aab08_row12_col1" class="data row12 col1" ><a href="https://www.barrons.com/articles/best-tech-stocks-to-buy-now-2026-dac5ca73?mod=bar_FV" target="_blank">The 3 Best Tech Stocks to Buy for 2026, According to Our Columnist</a></td>
#     </tr>
#     <tr>
#       <td id="T_aab08_row13_col0" class="data row13 col0" >04:13PM</td>
#       <td id="T_aab08_row13_col1" class="data row13 col1" ><a href="https://www.barrons.com/articles/us-mexico-canada-trade-agreement-trump-tariffs-ec1ab886?mod=bar_FV" target="_blank">U.S. Could Consider an Exit From Mexico and Canada Trade Deal, Official Says</a></td>
#     </tr>
#   </tbody>
# </table>
# <h2 style="text-align:left;">Noticias de AAPL</h2>
# <style type="text/css">
# #T_43e17 th {
#   text-align: center;
# }
# #T_43e17_row0_col0, #T_43e17_row2_col0, #T_43e17_row3_col0, #T_43e17_row5_col0, #T_43e17_row6_col0, #T_43e17_row7_col0, #T_43e17_row8_col0, #T_43e17_row9_col0, #T_43e17_row10_col0 {
#   text-align: right;
# }
# #T_43e17_row0_col1, #T_43e17_row2_col1, #T_43e17_row3_col1, #T_43e17_row5_col1, #T_43e17_row6_col1, #T_43e17_row7_col1, #T_43e17_row8_col1, #T_43e17_row9_col1, #T_43e17_row10_col1 {
#   text-align: left;
# }
# #T_43e17_row1_col0, #T_43e17_row4_col0 {
#   font-weight: bold;
#   text-align: right;
# }
# #T_43e17_row1_col1, #T_43e17_row4_col1 {
#   font-weight: bold;
#   text-align: left;
# }
# </style>
# <table id="T_43e17">
#   <thead>
#     <tr>
#       <th id="T_43e17_level0_col0" class="col_heading level0 col0" >fecha</th>
#       <th id="T_43e17_level0_col1" class="col_heading level0 col1" >título</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_43e17_row0_col0" class="data row0 col0" >---</td>
#       <td id="T_43e17_row0_col1" class="data row0 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_43e17_row1_col0" class="data row1 col0" ></td>
#       <td id="T_43e17_row1_col1" class="data row1 col1" >wsj</td>
#     </tr>
#     <tr>
#       <td id="T_43e17_row2_col0" class="data row2 col0" >02:23PM</td>
#       <td id="T_43e17_row2_col1" class="data row2 col1" ><a href="https://www.wsj.com/livecoverage/stock-market-today-dow-sp-500-nasdaq-12-08-2025/card/apple-s-chips-chief-says-he-isn-t-leaving-EbW6HzlnWZycLTHIPWgR?mod=wsj_FV" target="_blank">Apple's Chips Chief Says He Isn't Leaving</a></td>
#     </tr>
#     <tr>
#       <td id="T_43e17_row3_col0" class="data row3 col0" >---</td>
#       <td id="T_43e17_row3_col1" class="data row3 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_43e17_row4_col0" class="data row4 col0" >---</td>
#       <td id="T_43e17_row4_col1" class="data row4 col1" >barrons</td>
#     </tr>
#     <tr>
#       <td id="T_43e17_row5_col0" class="data row5 col0" >02:50PM</td>
#       <td id="T_43e17_row5_col1" class="data row5 col1" ><a href="https://www.barrons.com/articles/s-p-500-market-cap-revenue-etf-f079e636?mod=bar_FV" target="_blank">Look Past the S&P 500's Market Cap and Focus on Revenue Instead</a></td>
#     </tr>
#     <tr>
#       <td id="T_43e17_row6_col0" class="data row6 col0" >03:48PM</td>
#       <td id="T_43e17_row6_col1" class="data row6 col1" ><a href="https://www.barrons.com/articles/tech-stocks-buy-ai-meta-47d11a3a?mod=bar_FV" target="_blank">2 Reasons Tech Stocks Are Rise Past AI Worries</a></td>
#     </tr>
#     <tr>
#       <td id="T_43e17_row7_col0" class="data row7 col0" >02:00PM</td>
#       <td id="T_43e17_row7_col1" class="data row7 col1" ><a href="https://www.barrons.com/articles/meta-stock-price-tech-ai-buy-47d11a3a?mod=bar_FV" target="_blank">2 Reasons Meta and Other Tech Stocks Can Rise Past AI Worries</a></td>
#     </tr>
#     <tr>
#       <td id="T_43e17_row8_col0" class="data row8 col0" >12:52PM</td>
#       <td id="T_43e17_row8_col1" class="data row8 col1" ><a href="https://www.barrons.com/articles/tech-stocks-ai-rebound-analysts-47d11a3a?mod=bar_FV" target="_blank">Tech Stocks Are Rebounding. Two Reasons It Can Continue.</a></td>
#     </tr>
#     <tr>
#       <td id="T_43e17_row9_col0" class="data row9 col0" >08:17AM</td>
#       <td id="T_43e17_row9_col1" class="data row9 col1" ><a href="https://www.barrons.com/articles/walmart-stock-price-nasdaq-listing-tech-0b703456?mod=bar_FV" target="_blank">Walmart Stock Now Trades on the Nasdaq. Its Tech Transformation Is Real.</a></td>
#     </tr>
#     <tr>
#       <td id="T_43e17_row10_col0" class="data row10 col0" >07:21AM</td>
#       <td id="T_43e17_row10_col1" class="data row10 col1" ><a href="https://www.barrons.com/articles/walmart-stock-nasdaq-listing-0b703456?mod=bar_FV" target="_blank">Walmart Completes Move to Nasdaq, Sealing Its Tech Transformation</a></td>
#     </tr>
#   </tbody>
# </table>
# <h2 style="text-align:left;">Noticias de AMZN</h2>
# <style type="text/css">
# #T_bf7de th {
#   text-align: center;
# }
# #T_bf7de_row0_col0, #T_bf7de_row2_col0, #T_bf7de_row4_col0, #T_bf7de_row5_col0, #T_bf7de_row6_col0, #T_bf7de_row7_col0, #T_bf7de_row8_col0, #T_bf7de_row9_col0, #T_bf7de_row10_col0 {
#   text-align: right;
# }
# #T_bf7de_row0_col1, #T_bf7de_row2_col1, #T_bf7de_row4_col1, #T_bf7de_row5_col1, #T_bf7de_row6_col1, #T_bf7de_row7_col1, #T_bf7de_row8_col1, #T_bf7de_row9_col1, #T_bf7de_row10_col1 {
#   text-align: left;
# }
# #T_bf7de_row1_col0, #T_bf7de_row3_col0 {
#   font-weight: bold;
#   text-align: right;
# }
# #T_bf7de_row1_col1, #T_bf7de_row3_col1 {
#   font-weight: bold;
#   text-align: left;
# }
# </style>
# <table id="T_bf7de">
#   <thead>
#     <tr>
#       <th id="T_bf7de_level0_col0" class="col_heading level0 col0" >fecha</th>
#       <th id="T_bf7de_level0_col1" class="col_heading level0 col1" >título</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_bf7de_row0_col0" class="data row0 col0" >---</td>
#       <td id="T_bf7de_row0_col1" class="data row0 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_bf7de_row1_col0" class="data row1 col0" ></td>
#       <td id="T_bf7de_row1_col1" class="data row1 col1" >wsj</td>
#     </tr>
#     <tr>
#       <td id="T_bf7de_row2_col0" class="data row2 col0" >---</td>
#       <td id="T_bf7de_row2_col1" class="data row2 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_bf7de_row3_col0" class="data row3 col0" >---</td>
#       <td id="T_bf7de_row3_col1" class="data row3 col1" >barrons</td>
#     </tr>
#     <tr>
#       <td id="T_bf7de_row4_col0" class="data row4 col0" >02:50PM</td>
#       <td id="T_bf7de_row4_col1" class="data row4 col1" ><a href="https://www.barrons.com/articles/s-p-500-market-cap-revenue-etf-f079e636?mod=bar_FV" target="_blank">Look Past the S&P 500's Market Cap and Focus on Revenue Instead</a></td>
#     </tr>
#     <tr>
#       <td id="T_bf7de_row5_col0" class="data row5 col0" >01:24PM</td>
#       <td id="T_bf7de_row5_col1" class="data row5 col1" ><a href="https://www.barrons.com/articles/roku-stock-price-prediction-2026-d1ccd0e9?mod=bar_FV" target="_blank">Roku Stock Is a Top Pick for 2026 at 2 Wall Street Firms. Here's Why.</a></td>
#     </tr>
#     <tr>
#       <td id="T_bf7de_row6_col0" class="data row6 col0" >12:30AM</td>
#       <td id="T_bf7de_row6_col1" class="data row6 col1" ><a href="https://www.barrons.com/articles/costco-wholesale-earnings-stock-price-8a54af1e?mod=bar_FV" target="_blank">Can Costco's Earnings Report Silence Skeptics? What Could Revive the Stock.</a></td>
#     </tr>
#     <tr>
#       <td id="T_bf7de_row7_col0" class="data row7 col0" >06:09PM</td>
#       <td id="T_bf7de_row7_col1" class="data row7 col1" ><a href="https://www.barrons.com/articles/amazon-grocery-stock-0fe178af?mod=bar_FV" target="_blank">Amazon Expands Same-Day Grocery Delivery. Rival Stocks Are Falling.</a></td>
#     </tr>
#     <tr>
#       <td id="T_bf7de_row8_col0" class="data row8 col0" >03:32PM</td>
#       <td id="T_bf7de_row8_col1" class="data row8 col1" ><a href="https://www.barrons.com/articles/cisco-stock-highest-close-dot-com-bubble-burst-bde34a85?mod=bar_FV" target="_blank">It's a Big Day for Cisco Stock. It's on Track for Highest Close Since Dot-Com Bubble Burst.</a></td>
#     </tr>
#     <tr>
#       <td id="T_bf7de_row9_col0" class="data row9 col0" >09:30AM</td>
#       <td id="T_bf7de_row9_col1" class="data row9 col1" ><a href="https://www.barrons.com/articles/small-cap-stocks-s-p500-17241392?mod=bar_FV" target="_blank">Small-Cap Stocks May Be Ready to Outperform After Five Years of Lagging</a></td>
#     </tr>
#     <tr>
#       <td id="T_bf7de_row10_col0" class="data row10 col0" >07:35AM</td>
#       <td id="T_bf7de_row10_col1" class="data row10 col1" ><a href="https://www.barrons.com/articles/marvell-stock-chips-microsoft-amazon-9ea60f11?mod=bar_FV" target="_blank">Marvell Stock Falls on Microsoft, Amazon Fears. 'Block Out the Noise.'</a></td>
#     </tr>
#   </tbody>
# </table>
# <h2 style="text-align:left;">Noticias de GOOG</h2>
# <style type="text/css">
# #T_f0824 th {
#   text-align: center;
# }
# #T_f0824_row0_col0, #T_f0824_row2_col0 {
#   text-align: right;
# }
# #T_f0824_row0_col1, #T_f0824_row2_col1 {
#   text-align: left;
# }
# #T_f0824_row1_col0, #T_f0824_row3_col0 {
#   font-weight: bold;
#   text-align: right;
# }
# #T_f0824_row1_col1, #T_f0824_row3_col1 {
#   font-weight: bold;
#   text-align: left;
# }
# </style>
# <table id="T_f0824">
#   <thead>
#     <tr>
#       <th id="T_f0824_level0_col0" class="col_heading level0 col0" >fecha</th>
#       <th id="T_f0824_level0_col1" class="col_heading level0 col1" >título</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f0824_row0_col0" class="data row0 col0" >---</td>
#       <td id="T_f0824_row0_col1" class="data row0 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_f0824_row1_col0" class="data row1 col0" ></td>
#       <td id="T_f0824_row1_col1" class="data row1 col1" >wsj</td>
#     </tr>
#     <tr>
#       <td id="T_f0824_row2_col0" class="data row2 col0" >---</td>
#       <td id="T_f0824_row2_col1" class="data row2 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_f0824_row3_col0" class="data row3 col0" >---</td>
#       <td id="T_f0824_row3_col1" class="data row3 col1" >barrons</td>
#     </tr>
#   </tbody>
# </table>
# <h2 style="text-align:left;">Noticias de GOOGL</h2>
# <style type="text/css">
# #T_c554e th {
#   text-align: center;
# }
# #T_c554e_row0_col0, #T_c554e_row2_col0, #T_c554e_row4_col0, #T_c554e_row5_col0, #T_c554e_row6_col0 {
#   text-align: right;
# }
# #T_c554e_row0_col1, #T_c554e_row2_col1, #T_c554e_row4_col1, #T_c554e_row5_col1, #T_c554e_row6_col1 {
#   text-align: left;
# }
# #T_c554e_row1_col0, #T_c554e_row3_col0 {
#   font-weight: bold;
#   text-align: right;
# }
# #T_c554e_row1_col1, #T_c554e_row3_col1 {
#   font-weight: bold;
#   text-align: left;
# }
# </style>
# <table id="T_c554e">
#   <thead>
#     <tr>
#       <th id="T_c554e_level0_col0" class="col_heading level0 col0" >fecha</th>
#       <th id="T_c554e_level0_col1" class="col_heading level0 col1" >título</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c554e_row0_col0" class="data row0 col0" >---</td>
#       <td id="T_c554e_row0_col1" class="data row0 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_c554e_row1_col0" class="data row1 col0" ></td>
#       <td id="T_c554e_row1_col1" class="data row1 col1" >wsj</td>
#     </tr>
#     <tr>
#       <td id="T_c554e_row2_col0" class="data row2 col0" >---</td>
#       <td id="T_c554e_row2_col1" class="data row2 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_c554e_row3_col0" class="data row3 col0" >---</td>
#       <td id="T_c554e_row3_col1" class="data row3 col1" >barrons</td>
#     </tr>
#     <tr>
#       <td id="T_c554e_row4_col0" class="data row4 col0" >08:19AM</td>
#       <td id="T_c554e_row4_col1" class="data row4 col1" ><a href="https://www.barrons.com/articles/tesla-stock-price-robo-taxis-e5aabcbb?mod=bar_FV" target="_blank">Tesla Stock Slips. Analysts Are Split on Full-Self Driving Progress.</a></td>
#     </tr>
#     <tr>
#       <td id="T_c554e_row5_col0" class="data row5 col0" >07:46AM</td>
#       <td id="T_c554e_row5_col1" class="data row5 col1" ><a href="https://www.barrons.com/articles/ionq-d-wave-rigetti-stocks-quantum-computing-buy-a92da284?mod=bar_FV" target="_blank">IonQ, D-Wave, and Rigetti Stocks Are a Buy, Say Analysts. How the Quantum Pure Plays Stack Up.</a></td>
#     </tr>
#     <tr>
#       <td id="T_c554e_row6_col0" class="data row6 col0" >07:22AM</td>
#       <td id="T_c554e_row6_col1" class="data row6 col1" ><a href="https://www.barrons.com/articles/oracle-stock-earnings-federal-reserve-rate-cut-b67e85c6?mod=bar_FV" target="_blank">Oracle and the Fed Were Expected to Provide Wall Street With Answers. Only One Delivered.</a></td>
#     </tr>
#   </tbody>
# </table>
# <h2 style="text-align:left;">Noticias de META</h2>
# <style type="text/css">
# #T_2a3a3 th {
#   text-align: center;
# }
# #T_2a3a3_row0_col0, #T_2a3a3_row2_col0, #T_2a3a3_row4_col0, #T_2a3a3_row5_col0, #T_2a3a3_row6_col0, #T_2a3a3_row7_col0, #T_2a3a3_row8_col0 {
#   text-align: right;
# }
# #T_2a3a3_row0_col1, #T_2a3a3_row2_col1, #T_2a3a3_row4_col1, #T_2a3a3_row5_col1, #T_2a3a3_row6_col1, #T_2a3a3_row7_col1, #T_2a3a3_row8_col1 {
#   text-align: left;
# }
# #T_2a3a3_row1_col0, #T_2a3a3_row3_col0 {
#   font-weight: bold;
#   text-align: right;
# }
# #T_2a3a3_row1_col1, #T_2a3a3_row3_col1 {
#   font-weight: bold;
#   text-align: left;
# }
# </style>
# <table id="T_2a3a3">
#   <thead>
#     <tr>
#       <th id="T_2a3a3_level0_col0" class="col_heading level0 col0" >fecha</th>
#       <th id="T_2a3a3_level0_col1" class="col_heading level0 col1" >título</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2a3a3_row0_col0" class="data row0 col0" >---</td>
#       <td id="T_2a3a3_row0_col1" class="data row0 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_2a3a3_row1_col0" class="data row1 col0" ></td>
#       <td id="T_2a3a3_row1_col1" class="data row1 col1" >wsj</td>
#     </tr>
#     <tr>
#       <td id="T_2a3a3_row2_col0" class="data row2 col0" >---</td>
#       <td id="T_2a3a3_row2_col1" class="data row2 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_2a3a3_row3_col0" class="data row3 col0" >---</td>
#       <td id="T_2a3a3_row3_col1" class="data row3 col1" >barrons</td>
#     </tr>
#     <tr>
#       <td id="T_2a3a3_row4_col0" class="data row4 col0" >12:53PM</td>
#       <td id="T_2a3a3_row4_col1" class="data row4 col1" ><a href="https://www.barrons.com/articles/meta-ai-strategy-no-mans-land-3-stocks-bullish-technical-indicators-487e352d?mod=bar_FV" target="_blank">Meta's AI Strategy Is Stuck in No Man's Land. So Is the Stock.</a></td>
#     </tr>
#     <tr>
#       <td id="T_2a3a3_row5_col0" class="data row5 col0" >09:30AM</td>
#       <td id="T_2a3a3_row5_col1" class="data row5 col1" ><a href="https://www.barrons.com/articles/small-cap-stocks-s-p500-17241392?mod=bar_FV" target="_blank">Small-Cap Stocks May Be Ready to Outperform After Five Years of Lagging</a></td>
#     </tr>
#     <tr>
#       <td id="T_2a3a3_row6_col0" class="data row6 col0" >08:40AM</td>
#       <td id="T_2a3a3_row6_col1" class="data row6 col1" ><a href="https://www.barrons.com/articles/oracle-earnings-ai-stock-market-nvidia-d7585d45?mod=bar_FV" target="_blank">A Key Moment for AI Stocks Comes This Week-and It Has Nothing to Do With Nvidia</a></td>
#     </tr>
#     <tr>
#       <td id="T_2a3a3_row7_col0" class="data row7 col0" >03:48PM</td>
#       <td id="T_2a3a3_row7_col1" class="data row7 col1" ><a href="https://www.barrons.com/articles/tech-stocks-buy-ai-meta-47d11a3a?mod=bar_FV" target="_blank">2 Reasons Tech Stocks Are Rise Past AI Worries</a></td>
#     </tr>
#     <tr>
#       <td id="T_2a3a3_row8_col0" class="data row8 col0" >02:00PM</td>
#       <td id="T_2a3a3_row8_col1" class="data row8 col1" ><a href="https://www.barrons.com/articles/meta-stock-price-tech-ai-buy-47d11a3a?mod=bar_FV" target="_blank">2 Reasons Meta and Other Tech Stocks Can Rise Past AI Worries</a></td>
#     </tr>
#   </tbody>
# </table>
